# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier , RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as smf
import statsmodels
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn import metrics
import xgboost as xgb

# %%
dataset = pd.read_csv('desktop/en_yeni_pre_mart.csv')
dataset
# Out:
# /Users/barankilic/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (17,40,41,42,43,47,48,50,51,52,61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              id value_currency latest_status shipper_note  \
# 0      ZK0BMR15            EUR      CANCELED          NaN
# 1      S2ON3IKO            TRY     DELIVERED          NaN
# 2      YX0LEDBY            TRY     DELIVERED            -
# 3      GLPTVKOW            TRY     DELIVERED          NaN
# 4      JP610Q9M            TRY     DELIVERED          NaN
# ...         ...            ...           ...          ...
# 48376  6U2WWH09            TRY     DELIVERED          NaN
# 48377  XJO652GC            TRY     DELIVERED          NaN
# 48378  0BOTO0G4            TRY     DELIVERED          NaN
# 48379  8GINZKBD            TRY     DELIVERED          NaN
# 48380  0HIH977T            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 0                           NaN  2022-02-25 08:13:28.903
# 1                           NaN  2022-03-02 21:13:51.289
# 2                           NaN  2022-02-28 16:34:50.185
# 3      606ae737ad17691d3bdb3eba  2022-03-03 10:20:43.380
# 4      606ae737ad17691d3bdb3eba  2022-03-03 10:20:43.380
# ...                         ...                      ...
# 48376  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 48377  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 48378  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 48379  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 48380  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
#
#                      createdat    order_id                pricing_id  \
# 0      2022-02-17 09:45:20.166         NaN  620e1914c6ac5460e59eb2b4
# 1      2022-02-28 12:33:36.734         NaN  621cbb206a694311038625bd
# 2      2022-02-28 14:55:01.265           -  621ce232b282a66f326aea4c
# 3      2022-02-28 14:04:40.109  0040878360                       NaN
# 4      2022-02-28 14:04:40.286  0040867975                       NaN
# ...                        ...         ...                       ...
# 48376  2020-04-07 12:17:38.440         NaN  5e8c5f5b76cad97764139545
# 48377  2020-04-07 12:17:38.430         NaN  5e8c5f5b76cad97764139545
# 48378  2020-04-07 12:17:38.430         NaN  5e8c5f5b76cad97764139545
# 48379  2020-04-07 12:17:38.420         NaN  5e8c5f5b76cad97764139545
# 48380  2020-04-07 12:17:38.440         NaN  5e8c5f5b76cad97764139545
#
#        totalkgds  ... total_cost_amount cost_currency total_cost_amount_in_tl  \
# 0       1700.000  ...               NaN           NaN                     NaN
# 1        397.000  ...            765.09           TRY                  765.09
# 2      10000.000  ...           8000.00           TRY                 8000.00
# 3         27.744  ...           1572.00           TRY                 1572.00
# 4         31.200  ...             37.56           TRY                   37.56
# ...          ...  ...               ...           ...                     ...
# 48376    448.000  ...               NaN           NaN                     NaN
# 48377    448.000  ...               NaN           NaN                     NaN
# 48378    448.000  ...               NaN           NaN                     NaN
# 48379    448.000  ...               NaN           NaN                     NaN
# 48380    448.000  ...               NaN           NaN                     NaN
#
#       total_cost_amount_in_eur total_cost_amount_in_usd  \
# 0                          NaN                      NaN
# 1                        49.36                    55.23
# 2                       516.12                   577.47
# 3                       101.42                   113.47
# 4                         2.42                     2.71
# ...                        ...                      ...
# 48376                      NaN                      NaN
# 48377                      NaN                      NaN
# 48378                      NaN                      NaN
# 48379                      NaN                      NaN
# 48380                      NaN                      NaN
#
#       total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# 0                              NaN                           NaN
# 1                           765.09                         49.36
# 2                          8000.00                        516.12
# 3                          1572.00                        101.42
# 4                            37.56                          2.42
# ...                            ...                           ...
# 48376                          NaN                           NaN
# 48377                          NaN                           NaN
# 48378                          NaN                           NaN
# 48379                          NaN                           NaN
# 48380                          NaN                           NaN
#
#       total_trip_cost_amount_in_usd              routes   km
# 0                               NaN        Ankara_Essen  NaN
# 1                             55.23    İstanbul_Antalya  NaN
# 2                            577.47  Gaziantep_İstanbul  NaN
# 3                            113.47       Kocaeli_Bursa  NaN
# 4                              2.71       Kocaeli_Bursa  NaN
# ...                             ...                 ...  ...
# 48376                           NaN   İstanbul_İstanbul  1.0
# 48377                           NaN     İstanbul_Bitlis  NaN
# 48378                           NaN    İstanbul_Bayburt  NaN
# 48379                           NaN    İstanbul_Kayseri  NaN
# 48380                           NaN   İstanbul_İstanbul  1.0
#
# [48381 rows x 89 columns]

# %%
price_data = pd.read_excel('desktop/shipment.xlsx',sheet_name = 'Sheet1')
price_data
# Out:
#            İl          İlçe      Tarih kursunsuz_v_max pro_dizel  \
# 0    İstanbul  BUYUKCEKMECE 2020-03-01         6.59 TL    6.2 TL
# 1    İstanbul  BUYUKCEKMECE 2020-03-03         6.59 TL    6.2 TL
# 2    İstanbul  BUYUKCEKMECE 2020-03-04         6.59 TL    6.2 TL
# 3    İstanbul  BUYUKCEKMECE 2020-03-10         6.59 TL    6.2 TL
# 4    İstanbul  BUYUKCEKMECE 2020-03-11         5.99 TL   5.65 TL
# ..        ...           ...        ...             ...       ...
# 432  İstanbul  BUYUKCEKMECE 2022-03-09        20.35 TL  22.81 TL
# 433  İstanbul  BUYUKCEKMECE 2022-03-10        20.35 TL  22.81 TL
# 434  İstanbul  BUYUKCEKMECE 2022-03-11        20.38 TL  22.86 TL
# 435  İstanbul  BUYUKCEKMECE 2022-03-12        20.38 TL  22.86 TL
# 436  İstanbul  BUYUKCEKMECE 2022-03-15        20.38 TL  20.61 TL
#
#     V/MAX Dizel 10   Gazyağı Kalorifer Yakıtı %1 Kükürtlü Fuel Oil
# 0          6.24 TL    5.1 TL             4 TL              3.93 TL
# 1          6.24 TL    5.1 TL          3.95 TL              3.85 TL
# 2          6.24 TL    5.1 TL          4.04 TL              3.94 TL
# 3          6.24 TL    5.1 TL          3.67 TL              3.56 TL
# 4          5.69 TL   4.47 TL           3.2 TL              3.06 TL
# ..             ...       ...              ...                  ...
# 432       22.84 TL   20.9 TL         18.91 TL             16.48 TL
# 433       22.84 TL  22.95 TL         20.36 TL             17.38 TL
# 434       22.89 TL  20.93 TL         19.06 TL             16.68 TL
# 435       22.89 TL  18.65 TL         17.77 TL             16.24 TL
# 436       20.64 TL  18.65 TL         17.66 TL             15.81 TL
#
# [437 rows x 9 columns]

# %%
data = pd.concat([price_data.Tarih.astype(str), price_data.kursunsuz_v_max, price_data.pro_dizel], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tarih            437 non-null    object
#  1   kursunsuz_v_max  437 non-null    object
#  2   pro_dizel        437 non-null    object
# dtypes: object(3)
# memory usage: 10.4+ KB

# %%
dataset['Tarih']= dataset.pickup_start_date.str[:-13]
dataset['Tarih']
# Out:
# 0        2022-02-28
# 1        2022-02-28
# 2        2022-02-28
# 3        2022-02-28
# 4        2022-02-28
#             ...
# 48376    2020-04-09
# 48377    2020-04-09
# 48378    2020-04-09
# 48379    2020-04-09
# 48380    2020-04-09
# Name: Tarih, Length: 48381, dtype: object

# %%
inner_join = pd.merge(dataset, 
                      data, 
                      on ='Tarih', 
                      how ='inner')

# %%
inner_join
# Out:
#              id value_currency latest_status shipper_note  \
# 0      S6RF5HCR            TRY     DELIVERED          NaN
# 1      S6RF5HCR            TRY     DELIVERED          NaN
# 2      AVO6QRZW            TRY     DELIVERED          NaN
# 3      AVO6QRZW            TRY     DELIVERED          NaN
# 4      CGK5O6IM            TRY     DELIVERED          NaN
# ...         ...            ...           ...          ...
# 28729  0BOTO0G4            TRY     DELIVERED          NaN
# 28730  8GINZKBD            TRY     DELIVERED          NaN
# 28731  8GINZKBD            TRY     DELIVERED          NaN
# 28732  0HIH977T            TRY     DELIVERED          NaN
# 28733  0HIH977T            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 0                           NaN  2022-02-28 09:33:07.955
# 1                           NaN  2022-02-28 09:33:07.955
# 2                           NaN  2022-02-26 08:52:32.826
# 3                           NaN  2022-02-26 08:52:32.826
# 4                           NaN  2022-02-25 20:09:40.445
# ...                         ...                      ...
# 28729  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 28730  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 28731  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 28732  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 28733  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
#
#                      createdat order_id                pricing_id  totalkgds  \
# 0      2022-02-26 08:15:37.545      NaN  6219e19e4a36822d100072ef    10000.0
# 1      2022-02-26 08:15:37.545      NaN  6219e19e4a36822d100072ef    10000.0
# 2      2022-02-26 08:17:30.640      NaN  6219e2194a36822d100072f0    10000.0
# 3      2022-02-26 08:17:30.640      NaN  6219e2194a36822d100072f0    10000.0
# 4      2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# ...                        ...      ...                       ...        ...
# 28729  2020-04-07 12:17:38.430      NaN  5e8c5f5b76cad97764139545      448.0
# 28730  2020-04-07 12:17:38.420      NaN  5e8c5f5b76cad97764139545      448.0
# 28731  2020-04-07 12:17:38.420      NaN  5e8c5f5b76cad97764139545      448.0
# 28732  2020-04-07 12:17:38.440      NaN  5e8c5f5b76cad97764139545      448.0
# 28733  2020-04-07 12:17:38.440      NaN  5e8c5f5b76cad97764139545      448.0
#
#        ... total_cost_amount_in_eur total_cost_amount_in_usd  \
# 0      ...                   325.17                   364.71
# 1      ...                   325.17                   364.71
# 2      ...                   250.13                   280.54
# 3      ...                   250.13                   280.54
# 4      ...                   375.20                   420.82
# ...    ...                      ...                      ...
# 28729  ...                      NaN                      NaN
# 28730  ...                      NaN                      NaN
# 28731  ...                      NaN                      NaN
# 28732  ...                      NaN                      NaN
# 28733  ...                      NaN                      NaN
#
#       total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# 0                           5200.0                        325.17
# 1                           5200.0                        325.17
# 2                           4000.0                        250.13
# 3                           4000.0                        250.13
# 4                           6000.0                        375.20
# ...                            ...                           ...
# 28729                          NaN                           NaN
# 28730                          NaN                           NaN
# 28731                          NaN                           NaN
# 28732                          NaN                           NaN
# 28733                          NaN                           NaN
#
#       total_trip_cost_amount_in_usd             routes     km       Tarih  \
# 0                            364.71    Manisa_İstanbul    NaN  2022-02-26
# 1                            364.71    Manisa_İstanbul    NaN  2022-02-26
# 2                            280.54    Manisa_İstanbul    NaN  2022-02-26
# 3                            280.54    Manisa_İstanbul    NaN  2022-02-26
# 4                            420.82        Burdur_Bolu  566.4  2022-02-26
# ...                             ...                ...    ...         ...
# 28729                           NaN   İstanbul_Bayburt    NaN  2020-04-09
# 28730                           NaN   İstanbul_Kayseri    NaN  2020-04-09
# 28731                           NaN   İstanbul_Kayseri    NaN  2020-04-09
# 28732                           NaN  İstanbul_İstanbul    1.0  2020-04-09
# 28733                           NaN  İstanbul_İstanbul    1.0  2020-04-09
#
#       kursunsuz_v_max pro_dizel
# 0            16.77 TL     17 TL
# 1            16.77 TL     17 TL
# 2            16.77 TL     17 TL
# 3            16.77 TL     17 TL
# 4            16.77 TL     17 TL
# ...               ...       ...
# 28729         5.22 TL   5.45 TL
# 28730         5.22 TL   5.45 TL
# 28731         5.22 TL   5.45 TL
# 28732         5.22 TL   5.45 TL
# 28733         5.22 TL   5.45 TL
#
# [28734 rows x 92 columns]

# %%
inner_join['kursunsuz_v_max'] = inner_join['kursunsuz_v_max'].str[:-2]
inner_join['kursunsuz_v_max']
# Out:
# 0        16.77
# 1        16.77
# 2        16.77
# 3        16.77
# 4        16.77
#           ...
# 28729     5.22
# 28730     5.22
# 28731     5.22
# 28732     5.22
# 28733     5.22
# Name: kursunsuz_v_max, Length: 28734, dtype: object

# %%
inner_join['pro_dizel'] = inner_join['pro_dizel'].str[:-2]
inner_join['pro_dizel']
# Out:
# 0          17
# 1          17
# 2          17
# 3          17
# 4          17
#          ...
# 28729    5.45
# 28730    5.45
# 28731    5.45
# 28732    5.45
# 28733    5.45
# Name: pro_dizel, Length: 28734, dtype: object

# %%
inner_join['pro_dizel'] = inner_join.pro_dizel.astype(float)
inner_join.kursunsuz_v_max = inner_join.kursunsuz_v_max.astype(float)
inner_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28734 entries, 0 to 28733
# Data columns (total 92 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   id                                          28734 non-null  object
#  1   value_currency                              28734 non-null  object
#  2   latest_status                               28734 non-null  object
#  3   shipper_note                                3218 non-null   object
#  4   updatedby                                   22662 non-null  object
#  5   updatedat                                   28734 non-null  object
#  6   createdat                                   28734 non-null  object
#  7   order_id                                    10066 non-null  object
#  8   pricing_id                                  19740 non-null  object
#  9   totalkgds                                   28734 non-null  float64
#  10  pickup_start_date                           28734 non-null  object
#  11  pickup_end_date                             28734 non-null  object
#  12  customer_representative_name                27356 non-null  object
#  13  customer_representative_id                  27356 non-null  object
#  14  pickup_district                             28644 non-null  object
#  15  pickup_company                              28734 non-null  object
#  16  pickup_city                                 28734 non-null  object
#  17  pickup_zipcode                              92 non-null     object
#  18  pickup_name                                 28734 non-null  object
#  19  pickup_address_type                         28734 non-null  object
#  20  pickup_country_id                           28734 non-null  object
#  21  dropoff_country_id                          28734 non-null  object
#  22  source_id                                   19740 non-null  float64
#  23  category                                    28734 non-null  object
#  24  dropoff_district                            27902 non-null  object
#  25  dropoff_company                             28734 non-null  object
#  26  dropoff_city                                28734 non-null  object
#  27  dropoff_zipcode                             678 non-null    object
#  28  dropoff_name                                28732 non-null  object
#  29  dropoff_address_type                        25132 non-null  object
#  30  value                                       28734 non-null  float64
#  31  waybillnumber                               8160 non-null   object
#  32  price_base_amount                           24620 non-null  float64
#  33  price_total_amount                          24620 non-null  float64
#  34  price_tax_amount                            24620 non-null  float64
#  35  price_currency                              24620 non-null  object
#  36  discount_status                             4676 non-null   object
#  37  price_type                                  4796 non-null   object
#  38  expected_delivery_date                      23212 non-null  object
#  39  shipment_type                               28734 non-null  object
#  40  vehicle_type                                11274 non-null  object
#  41  vehicle_package_type                        11154 non-null  object
#  42  vehicle_body_type                           11274 non-null  object
#  43  vehicle_way_of_loading                      11274 non-null  object
#  44  vehicle_tonnage_per_vehicle                 11274 non-null  float64
#  45  approved_status_date                        16704 non-null  object
#  46  in_transit_status_date                      9780 non-null   object
#  47  in_delivery_status_date                     5940 non-null   object
#  48  in_arrival_crossdock_status_date            70 non-null     object
#  49  delivered_status_date                       22382 non-null  object
#  50  in_crossdock_status_date                    3318 non-null   object
#  51  in_intermediate_transportation_status_date  70 non-null     object
#  52  in_main_transportation_status_date          1392 non-null   object
#  53  in_pickup_status_date                       11788 non-null  object
#  54  tenant_id                                   28734 non-null  object
#  55  user_id                                     28696 non-null  object
#  56  latest_pod_status                           28734 non-null  object
#  57  latest_invoice_status                       28734 non-null  object
#  58  payment_status                              19740 non-null  object
#  59  payment_id                                  58 non-null     object
#  60  payment_option                              28734 non-null  object
#  61  invoice_type                                14666 non-null  object
#  62  invoice_document_id                         14666 non-null  object
#  63  invoice_id                                  3362 non-null   float64
#  64  latest_status_desc_code                     6464 non-null   object
#  65  title                                       28684 non-null  object
#  66  tenant_createat                             28734 non-null  object
#  67  tenant_type                                 28734 non-null  object
#  68  invoice_company_title                       28684 non-null  object
#  69  tenant_signup_flow                          28734 non-null  object
#  70  user_email                                  27152 non-null  object
#  71  user_role                                   27152 non-null  object
#  72  assigned_trip_count                         14090 non-null  float64
#  73  eur_tl                                      28734 non-null  float64
#  74  usd_tl                                      28734 non-null  float64
#  75  eur_usd                                     28734 non-null  float64
#  76  price_base_amount_in_tl                     24620 non-null  float64
#  77  price_base_amount_in_usd                    24620 non-null  float64
#  78  price_base_amount_in_eur                    24620 non-null  float64
#  79  total_cost_amount                           16562 non-null  float64
#  80  cost_currency                               16562 non-null  object
#  81  total_cost_amount_in_tl                     16562 non-null  float64
#  82  total_cost_amount_in_eur                    16562 non-null  float64
#  83  total_cost_amount_in_usd                    16562 non-null  float64
#  84  total_trip_cost_amount_in_tl                16562 non-null  float64
#  85  total_trip_cost_amount_in_eur               16562 non-null  float64
#  86  total_trip_cost_amount_in_usd               16562 non-null  float64
#  87  routes                                      28734 non-null  object
#  88  km                                          13810 non-null  float64
#  89  Tarih                                       28734 non-null  object
#  90  kursunsuz_v_max                             28734 non-null  float64
#  91  pro_dizel                                   28734 non-null  float64
# dtypes: float64(25), object(67)
# memory usage: 20.4+ MB

# %%
dataset = inner_join
dataset
# Out:
#              id value_currency latest_status shipper_note  \
# 0      S6RF5HCR            TRY     DELIVERED          NaN
# 1      S6RF5HCR            TRY     DELIVERED          NaN
# 2      AVO6QRZW            TRY     DELIVERED          NaN
# 3      AVO6QRZW            TRY     DELIVERED          NaN
# 4      CGK5O6IM            TRY     DELIVERED          NaN
# ...         ...            ...           ...          ...
# 28729  0BOTO0G4            TRY     DELIVERED          NaN
# 28730  8GINZKBD            TRY     DELIVERED          NaN
# 28731  8GINZKBD            TRY     DELIVERED          NaN
# 28732  0HIH977T            TRY     DELIVERED          NaN
# 28733  0HIH977T            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 0                           NaN  2022-02-28 09:33:07.955
# 1                           NaN  2022-02-28 09:33:07.955
# 2                           NaN  2022-02-26 08:52:32.826
# 3                           NaN  2022-02-26 08:52:32.826
# 4                           NaN  2022-02-25 20:09:40.445
# ...                         ...                      ...
# 28729  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 28730  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 28731  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 28732  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
# 28733  5fb29424ebbf435b44d7b9a2  2021-12-01 16:00:07.453
#
#                      createdat order_id                pricing_id  totalkgds  \
# 0      2022-02-26 08:15:37.545      NaN  6219e19e4a36822d100072ef    10000.0
# 1      2022-02-26 08:15:37.545      NaN  6219e19e4a36822d100072ef    10000.0
# 2      2022-02-26 08:17:30.640      NaN  6219e2194a36822d100072f0    10000.0
# 3      2022-02-26 08:17:30.640      NaN  6219e2194a36822d100072f0    10000.0
# 4      2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# ...                        ...      ...                       ...        ...
# 28729  2020-04-07 12:17:38.430      NaN  5e8c5f5b76cad97764139545      448.0
# 28730  2020-04-07 12:17:38.420      NaN  5e8c5f5b76cad97764139545      448.0
# 28731  2020-04-07 12:17:38.420      NaN  5e8c5f5b76cad97764139545      448.0
# 28732  2020-04-07 12:17:38.440      NaN  5e8c5f5b76cad97764139545      448.0
# 28733  2020-04-07 12:17:38.440      NaN  5e8c5f5b76cad97764139545      448.0
#
#        ... total_cost_amount_in_eur total_cost_amount_in_usd  \
# 0      ...                   325.17                   364.71
# 1      ...                   325.17                   364.71
# 2      ...                   250.13                   280.54
# 3      ...                   250.13                   280.54
# 4      ...                   375.20                   420.82
# ...    ...                      ...                      ...
# 28729  ...                      NaN                      NaN
# 28730  ...                      NaN                      NaN
# 28731  ...                      NaN                      NaN
# 28732  ...                      NaN                      NaN
# 28733  ...                      NaN                      NaN
#
#       total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# 0                           5200.0                        325.17
# 1                           5200.0                        325.17
# 2                           4000.0                        250.13
# 3                           4000.0                        250.13
# 4                           6000.0                        375.20
# ...                            ...                           ...
# 28729                          NaN                           NaN
# 28730                          NaN                           NaN
# 28731                          NaN                           NaN
# 28732                          NaN                           NaN
# 28733                          NaN                           NaN
#
#       total_trip_cost_amount_in_usd             routes     km       Tarih  \
# 0                            364.71    Manisa_İstanbul    NaN  2022-02-26
# 1                            364.71    Manisa_İstanbul    NaN  2022-02-26
# 2                            280.54    Manisa_İstanbul    NaN  2022-02-26
# 3                            280.54    Manisa_İstanbul    NaN  2022-02-26
# 4                            420.82        Burdur_Bolu  566.4  2022-02-26
# ...                             ...                ...    ...         ...
# 28729                           NaN   İstanbul_Bayburt    NaN  2020-04-09
# 28730                           NaN   İstanbul_Kayseri    NaN  2020-04-09
# 28731                           NaN   İstanbul_Kayseri    NaN  2020-04-09
# 28732                           NaN  İstanbul_İstanbul    1.0  2020-04-09
# 28733                           NaN  İstanbul_İstanbul    1.0  2020-04-09
#
#       kursunsuz_v_max pro_dizel
# 0               16.77     17.00
# 1               16.77     17.00
# 2               16.77     17.00
# 3               16.77     17.00
# 4               16.77     17.00
# ...               ...       ...
# 28729            5.22      5.45
# 28730            5.22      5.45
# 28731            5.22      5.45
# 28732            5.22      5.45
# 28733            5.22      5.45
#
# [28734 rows x 92 columns]

# %%
dataset = dataset[dataset.total_cost_amount_in_tl > 10]
#dataset = dataset[dataset.total_cost_amount_in_tl < 10000]

# %%
# Get Delivered Shipments
accepted = ('APPROVED', 'IN_TRANSIT', 'IN_DELIVERY', 'IN_CROSSDOCK', 'DELIVERED', 'IN_PICKUP')

dataset = dataset[dataset.latest_status.isin(accepted)]
dataset
# Out:
#              id value_currency latest_status shipper_note  \
# 0      S6RF5HCR            TRY     DELIVERED          NaN
# 1      S6RF5HCR            TRY     DELIVERED          NaN
# 2      AVO6QRZW            TRY     DELIVERED          NaN
# 3      AVO6QRZW            TRY     DELIVERED          NaN
# 4      CGK5O6IM            TRY     DELIVERED          NaN
# ...         ...            ...           ...          ...
# 25867  9SW0FTNN            TRY     DELIVERED          NaN
# 25870  A437BSLV            TRY     DELIVERED          NaN
# 25871  A437BSLV            TRY     DELIVERED          NaN
# 26286  7B67CBV5            TRY     DELIVERED          NaN
# 26287  7B67CBV5            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 0                           NaN  2022-02-28 09:33:07.955
# 1                           NaN  2022-02-28 09:33:07.955
# 2                           NaN  2022-02-26 08:52:32.826
# 3                           NaN  2022-02-26 08:52:32.826
# 4                           NaN  2022-02-25 20:09:40.445
# ...                         ...                      ...
# 25867  5fb29424ebbf435b44d7b9a2  2021-12-01 15:34:40.770
# 25870  5fb29424ebbf435b44d7b9a2  2021-12-01 15:34:52.342
# 25871  5fb29424ebbf435b44d7b9a2  2021-12-01 15:34:52.342
# 26286  5fb29424ebbf435b44d7b9a2  2021-12-01 15:32:01.175
# 26287  5fb29424ebbf435b44d7b9a2  2021-12-01 15:32:01.175
#
#                      createdat order_id                pricing_id  totalkgds  \
# 0      2022-02-26 08:15:37.545      NaN  6219e19e4a36822d100072ef    10000.0
# 1      2022-02-26 08:15:37.545      NaN  6219e19e4a36822d100072ef    10000.0
# 2      2022-02-26 08:17:30.640      NaN  6219e2194a36822d100072f0    10000.0
# 3      2022-02-26 08:17:30.640      NaN  6219e2194a36822d100072f0    10000.0
# 4      2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# ...                        ...      ...                       ...        ...
# 25867  2021-01-14 19:48:45.133      NaN  60009fbe49885878b863095f      480.0
# 25870  2021-01-14 19:48:45.153      NaN  60009fbe49885878b863095f      480.0
# 25871  2021-01-14 19:48:45.153      NaN  60009fbe49885878b863095f      480.0
# 26286  2020-12-29 07:58:12.796      NaN  5feae18db973bb2a9e4fa09e      720.0
# 26287  2020-12-29 07:58:12.796      NaN  5feae18db973bb2a9e4fa09e      720.0
#
#        ... total_cost_amount_in_eur total_cost_amount_in_usd  \
# 0      ...                   325.17                   364.71
# 1      ...                   325.17                   364.71
# 2      ...                   250.13                   280.54
# 3      ...                   250.13                   280.54
# 4      ...                   375.20                   420.82
# ...    ...                      ...                      ...
# 25867  ...                     6.09                     7.27
# 25870  ...                     6.09                     7.27
# 25871  ...                     6.09                     7.27
# 26286  ...                    28.63                    34.87
# 26287  ...                    28.63                    34.87
#
#       total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# 0                          5200.00                        325.17
# 1                          5200.00                        325.17
# 2                          4000.00                        250.13
# 3                          4000.00                        250.13
# 4                          6000.00                        375.20
# ...                            ...                           ...
# 25867                        62.77                          6.09
# 25870                        62.77                          6.09
# 25871                        62.77                          6.09
# 26286                       300.00                         28.63
# 26287                       300.00                         28.63
#
#       total_trip_cost_amount_in_usd           routes     km       Tarih  \
# 0                            364.71  Manisa_İstanbul    NaN  2022-02-26
# 1                            364.71  Manisa_İstanbul    NaN  2022-02-26
# 2                            280.54  Manisa_İstanbul    NaN  2022-02-26
# 3                            280.54  Manisa_İstanbul    NaN  2022-02-26
# 4                            420.82      Burdur_Bolu  566.4  2022-02-26
# ...                             ...              ...    ...         ...
# 25867                          7.27    Kocaeli_İzmir  461.8  2021-01-14
# 25870                          7.27    Kocaeli_İzmir  461.8  2021-01-14
# 25871                          7.27    Kocaeli_İzmir  461.8  2021-01-14
# 26286                         34.87  İstanbul_Yalova    NaN  2020-12-29
# 26287                         34.87  İstanbul_Yalova    NaN  2020-12-29
#
#       kursunsuz_v_max pro_dizel
# 0               16.77     17.00
# 1               16.77     17.00
# 2               16.77     17.00
# 3               16.77     17.00
# 4               16.77     17.00
# ...               ...       ...
# 25867            7.20      6.59
# 25870            7.20      6.59
# 25871            7.20      6.59
# 26286            7.18      6.57
# 26287            7.18      6.57
#
# [15382 rows x 92 columns]

# %%
# GET pickup and dropoffs
routes = ('Bursa_Kocaeli', 'İzmir_Balıkesir', 'Konya_Afyonkarahisar', 'Afyonkarahisar_Afyonkarahisar', 'Kocaeli_Kocaeli', 'Bursa_Bursa', 'Bursa_Balıkesir', 'Kocaeli_Erzurum','Balıkesir_Balıkesir','İstanbul_İstanbul','Kocaeli_İstanbul','Kayseri_Afyonkarahisar','İstanbul_İzmir','Burdur_Bolu','Kocaeli_Malatya','Manisa_Balıkesir','İstanbul_Kocaeli','Balıkesir_Bursa','Hatay_Osmaniye','Kocaeli_İzmir','Sakarya_Kocaeli','İstanbul_Ankara','Bursa_Kayseri','Bursa_İstanbul','Bursa_İzmir', 'Yozgat_Afyonkarahisar', 'Bursa_Afyonkarahisar','İzmir_Afyonkarahisar', 'Bitlis_Afyonkarahisar','Sivas_Afyonkarahisar')
#routes = (['İstanbul_İstanbul'])
dataset = dataset[dataset.routes.isin(routes)]
dataset
# Out:
#              id value_currency latest_status shipper_note  \
# 4      CGK5O6IM            TRY     DELIVERED          NaN
# 5      CGK5O6IM            TRY     DELIVERED          NaN
# 6      6S0LETNH            TRY     DELIVERED          NaN
# 7      6S0LETNH            TRY     DELIVERED          NaN
# 14     OBTL48W8            TRY     DELIVERED          NaN
# ...         ...            ...           ...          ...
# 24935  VE6UGOBR            TRY     DELIVERED          NaN
# 25866  9SW0FTNN            TRY     DELIVERED          NaN
# 25867  9SW0FTNN            TRY     DELIVERED          NaN
# 25870  A437BSLV            TRY     DELIVERED          NaN
# 25871  A437BSLV            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 4                           NaN  2022-02-25 20:09:40.445
# 5                           NaN  2022-02-25 20:09:40.445
# 6                           NaN  2022-02-27 19:47:15.280
# 7                           NaN  2022-02-27 19:47:15.280
# 14                          NaN  2022-02-25 14:27:07.789
# ...                         ...                      ...
# 24935  5fb29424ebbf435b44d7b9a2  2021-12-01 15:56:20.245
# 25866  5fb29424ebbf435b44d7b9a2  2021-12-01 15:34:40.770
# 25867  5fb29424ebbf435b44d7b9a2  2021-12-01 15:34:40.770
# 25870  5fb29424ebbf435b44d7b9a2  2021-12-01 15:34:52.342
# 25871  5fb29424ebbf435b44d7b9a2  2021-12-01 15:34:52.342
#
#                      createdat order_id                pricing_id  totalkgds  \
# 4      2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# 5      2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# 6      2022-02-25 12:13:07.325      NaN  6218c7d260db324ef06b4be1    15000.0
# 7      2022-02-25 12:13:07.325      NaN  6218c7d260db324ef06b4be1    15000.0
# 14     2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# ...                        ...      ...                       ...        ...
# 24935  2021-02-26 13:54:38.942      NaN  6038fd9ad4c3a94d37ec7bd8    19800.0
# 25866  2021-01-14 19:48:45.133      NaN  60009fbe49885878b863095f      480.0
# 25867  2021-01-14 19:48:45.133      NaN  60009fbe49885878b863095f      480.0
# 25870  2021-01-14 19:48:45.153      NaN  60009fbe49885878b863095f      480.0
# 25871  2021-01-14 19:48:45.153      NaN  60009fbe49885878b863095f      480.0
#
#        ... total_cost_amount_in_eur total_cost_amount_in_usd  \
# 4      ...                   375.20                   420.82
# 5      ...                   375.20                   420.82
# 6      ...                    75.04                    84.16
# 7      ...                    75.04                    84.16
# 14     ...                   375.20                   420.82
# ...    ...                      ...                      ...
# 24935  ...                   151.10                   183.15
# 25866  ...                     6.09                     7.27
# 25867  ...                     6.09                     7.27
# 25870  ...                     6.09                     7.27
# 25871  ...                     6.09                     7.27
#
#       total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# 4                          6000.00                        375.20
# 5                          6000.00                        375.20
# 6                          1200.00                         75.04
# 7                          1200.00                         75.04
# 14                         6000.00                        375.20
# ...                            ...                           ...
# 24935                      1500.00                        151.10
# 25866                        62.77                          6.09
# 25867                        62.77                          6.09
# 25870                        62.77                          6.09
# 25871                        62.77                          6.09
#
#       total_trip_cost_amount_in_usd             routes     km       Tarih  \
# 4                            420.82        Burdur_Bolu  566.4  2022-02-26
# 5                            420.82        Burdur_Bolu  566.4  2022-02-26
# 6                             84.16  İstanbul_İstanbul    1.0  2022-02-26
# 7                             84.16  İstanbul_İstanbul    1.0  2022-02-26
# 14                           420.82        Burdur_Bolu  566.4  2022-02-26
# ...                             ...                ...    ...         ...
# 24935                        183.15  İstanbul_İstanbul    1.0  2021-02-26
# 25866                          7.27      Kocaeli_İzmir  461.8  2021-01-14
# 25867                          7.27      Kocaeli_İzmir  461.8  2021-01-14
# 25870                          7.27      Kocaeli_İzmir  461.8  2021-01-14
# 25871                          7.27      Kocaeli_İzmir  461.8  2021-01-14
#
#       kursunsuz_v_max pro_dizel
# 4               16.77     17.00
# 5               16.77     17.00
# 6               16.77     17.00
# 7               16.77     17.00
# 14              16.77     17.00
# ...               ...       ...
# 24935            7.21      6.60
# 25866            7.20      6.59
# 25867            7.20      6.59
# 25870            7.20      6.59
# 25871            7.20      6.59
#
# [9172 rows x 92 columns]

# %%
#Split Data by Shipment Type
dataset = dataset[dataset.shipment_type == 'FTL']
orj_data = dataset
dataset
# Out:
#              id value_currency latest_status shipper_note  \
# 4      CGK5O6IM            TRY     DELIVERED          NaN
# 5      CGK5O6IM            TRY     DELIVERED          NaN
# 6      6S0LETNH            TRY     DELIVERED          NaN
# 7      6S0LETNH            TRY     DELIVERED          NaN
# 14     OBTL48W8            TRY     DELIVERED          NaN
# ...         ...            ...           ...          ...
# 21895  S59VBYA6            TRY     DELIVERED          NaN
# 21930  38E131PT            TRY     DELIVERED          NaN
# 21931  38E131PT            TRY     DELIVERED          NaN
# 21994  WRSO6RD9            TRY     DELIVERED          NaN
# 21995  WRSO6RD9            TRY     DELIVERED          NaN
#
#                       updatedby                updatedat  \
# 4                           NaN  2022-02-25 20:09:40.445
# 5                           NaN  2022-02-25 20:09:40.445
# 6                           NaN  2022-02-27 19:47:15.280
# 7                           NaN  2022-02-27 19:47:15.280
# 14                          NaN  2022-02-25 14:27:07.789
# ...                         ...                      ...
# 21895  5fb29424ebbf435b44d7b9a2  2021-12-01 15:51:04.795
# 21930  5fb29424ebbf435b44d7b9a2  2021-12-01 15:29:07.350
# 21931  5fb29424ebbf435b44d7b9a2  2021-12-01 15:29:07.350
# 21994  5fb29424ebbf435b44d7b9a2  2021-12-01 15:57:14.235
# 21995  5fb29424ebbf435b44d7b9a2  2021-12-01 15:57:14.235
#
#                      createdat order_id                pricing_id  totalkgds  \
# 4      2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# 5      2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# 6      2022-02-25 12:13:07.325      NaN  6218c7d260db324ef06b4be1    15000.0
# 7      2022-02-25 12:13:07.325      NaN  6218c7d260db324ef06b4be1    15000.0
# 14     2022-02-24 14:05:55.463      NaN  621790b87f725a14629d28ff    25000.0
# ...                        ...      ...                       ...        ...
# 21895  2021-05-19 11:09:45.548      NaN  60a4f1f7a4eb0c0c6dcc40df     1000.0
# 21930  2021-05-19 11:05:16.868      NaN  60a4f0eaa4eb0c0c6dcc40da     1000.0
# 21931  2021-05-19 11:05:16.868      NaN  60a4f0eaa4eb0c0c6dcc40da     1000.0
# 21994  2021-05-19 11:06:14.385      NaN  60a4f123a4eb0c0c6dcc40db     1000.0
# 21995  2021-05-19 11:06:14.385      NaN  60a4f123a4eb0c0c6dcc40db     1000.0
#
#        ... total_cost_amount_in_eur total_cost_amount_in_usd  \
# 4      ...                   375.20                   420.82
# 5      ...                   375.20                   420.82
# 6      ...                    75.04                    84.16
# 7      ...                    75.04                    84.16
# 14     ...                   375.20                   420.82
# ...    ...                      ...                      ...
# 21895  ...                    54.00                    65.92
# 21930  ...                    54.00                    65.92
# 21931  ...                    54.00                    65.92
# 21994  ...                    58.91                    71.92
# 21995  ...                    58.91                    71.92
#
#       total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# 4                           6000.0                        375.20
# 5                           6000.0                        375.20
# 6                           1200.0                         75.04
# 7                           1200.0                         75.04
# 14                          6000.0                        375.20
# ...                            ...                           ...
# 21895                          0.0                          0.00
# 21930                        550.0                         54.00
# 21931                        550.0                         54.00
# 21994                        600.0                         58.91
# 21995                        600.0                         58.91
#
#       total_trip_cost_amount_in_usd             routes     km       Tarih  \
# 4                            420.82        Burdur_Bolu  566.4  2022-02-26
# 5                            420.82        Burdur_Bolu  566.4  2022-02-26
# 6                             84.16  İstanbul_İstanbul    1.0  2022-02-26
# 7                             84.16  İstanbul_İstanbul    1.0  2022-02-26
# 14                           420.82        Burdur_Bolu  566.4  2022-02-26
# ...                             ...                ...    ...         ...
# 21895                          0.00   Kocaeli_İstanbul   94.1  2021-05-12
# 21930                         65.92   Kocaeli_İstanbul   94.1  2021-05-07
# 21931                         65.92   Kocaeli_İstanbul   94.1  2021-05-07
# 21994                         71.92   Kocaeli_İstanbul   94.1  2021-05-07
# 21995                         71.92   Kocaeli_İstanbul   94.1  2021-05-07
#
#       kursunsuz_v_max pro_dizel
# 4               16.77     17.00
# 5               16.77     17.00
# 6               16.77     17.00
# 7               16.77     17.00
# 14              16.77     17.00
# ...               ...       ...
# 21895            7.07      6.43
# 21930            7.07      6.43
# 21931            7.07      6.43
# 21994            7.07      6.43
# 21995            7.07      6.43
#
# [4662 rows x 92 columns]

# %%
# Get Applicable Columns
dataset = pd.concat([dataset['latest_status'],dataset['totalkgds'],dataset['pickup_city'],dataset['dropoff_city'] ,dataset['pickup_address_type'], dataset['dropoff_address_type'],
                  dataset['category'], dataset['price_type'], 
                  dataset['shipment_type'], dataset['vehicle_type'],dataset['vehicle_body_type'],
                  dataset['vehicle_package_type'], dataset['vehicle_way_of_loading'],
                  dataset['vehicle_tonnage_per_vehicle'],dataset['payment_option'],
                  dataset['invoice_type'], dataset['tenant_signup_flow'], 
                  dataset['total_cost_amount_in_tl'], dataset['usd_tl'],
                  dataset['price_base_amount_in_tl']
                 ,dataset['routes'], dataset['km'],dataset['kursunsuz_v_max'],dataset['pro_dizel']], axis = 1)
dataset
# Out:
#       latest_status  totalkgds pickup_city dropoff_city pickup_address_type  \
# 4         DELIVERED    25000.0      Burdur         Bolu             FACTORY
# 5         DELIVERED    25000.0      Burdur         Bolu             FACTORY
# 6         DELIVERED    15000.0    İstanbul     İstanbul             FACTORY
# 7         DELIVERED    15000.0    İstanbul     İstanbul             FACTORY
# 14        DELIVERED    25000.0      Burdur         Bolu             FACTORY
# ...             ...        ...         ...          ...                 ...
# 21895     DELIVERED     1000.0     Kocaeli     İstanbul             FACTORY
# 21930     DELIVERED     1000.0     Kocaeli     İstanbul             FACTORY
# 21931     DELIVERED     1000.0     Kocaeli     İstanbul             FACTORY
# 21994     DELIVERED     1000.0     Kocaeli     İstanbul             FACTORY
# 21995     DELIVERED     1000.0     Kocaeli     İstanbul             FACTORY
#
#       dropoff_address_type  category price_type shipment_type vehicle_type  \
# 4                  FACTORY  DRY_FOOD        NaN           FTL   SEMI_TRUCK
# 5                  FACTORY  DRY_FOOD        NaN           FTL   SEMI_TRUCK
# 6                    OTHER  CHEMICAL     MANUAL           FTL  _10_WHEELER
# 7                    OTHER  CHEMICAL     MANUAL           FTL  _10_WHEELER
# 14                 FACTORY  DRY_FOOD        NaN           FTL   SEMI_TRUCK
# ...                    ...       ...        ...           ...          ...
# 21895                OTHER     BUILD        NaN           FTL        OTHER
# 21930                OTHER     BUILD        NaN           FTL        OTHER
# 21931                OTHER     BUILD        NaN           FTL        OTHER
# 21994                OTHER     BUILD        NaN           FTL        OTHER
# 21995                OTHER     BUILD        NaN           FTL        OTHER
#
#        ... payment_option invoice_type tenant_signup_flow  \
# 4      ...      PAY_LATER    E_INVOICE        SELF_SIGNUP
# 5      ...      PAY_LATER    E_INVOICE        SELF_SIGNUP
# 6      ...      PAY_LATER    E_INVOICE        SELF_SIGNUP
# 7      ...      PAY_LATER    E_INVOICE        SELF_SIGNUP
# 14     ...      PAY_LATER    E_INVOICE        SELF_SIGNUP
# ...    ...            ...          ...                ...
# 21895  ...      PAY_LATER          NaN        SELF_SIGNUP
# 21930  ...      PAY_LATER          NaN        SELF_SIGNUP
# 21931  ...      PAY_LATER          NaN        SELF_SIGNUP
# 21994  ...      PAY_LATER          NaN        SELF_SIGNUP
# 21995  ...      PAY_LATER          NaN        SELF_SIGNUP
#
#        total_cost_amount_in_tl   usd_tl price_base_amount_in_tl  \
# 4                       6000.0  14.2580                  6476.0
# 5                       6000.0  14.2580                  6476.0
# 6                       1200.0  14.2580                  1450.0
# 7                       1200.0  14.2580                  1450.0
# 14                      6000.0  14.2580                  6476.0
# ...                        ...      ...                     ...
# 21895                    550.0   8.3016                   505.0
# 21930                    550.0   8.3211                   505.0
# 21931                    550.0   8.3211                   505.0
# 21994                    600.0   8.3211                   505.0
# 21995                    600.0   8.3211                   505.0
#
#                   routes     km  kursunsuz_v_max  pro_dizel
# 4            Burdur_Bolu  566.4            16.77      17.00
# 5            Burdur_Bolu  566.4            16.77      17.00
# 6      İstanbul_İstanbul    1.0            16.77      17.00
# 7      İstanbul_İstanbul    1.0            16.77      17.00
# 14           Burdur_Bolu  566.4            16.77      17.00
# ...                  ...    ...              ...        ...
# 21895   Kocaeli_İstanbul   94.1             7.07       6.43
# 21930   Kocaeli_İstanbul   94.1             7.07       6.43
# 21931   Kocaeli_İstanbul   94.1             7.07       6.43
# 21994   Kocaeli_İstanbul   94.1             7.07       6.43
# 21995   Kocaeli_İstanbul   94.1             7.07       6.43
#
# [4662 rows x 24 columns]

# %%
dataset = dataset.drop(columns = 'shipment_type')
dataset = dataset.drop(columns = 'latest_status')
dataset = dataset.drop(columns = 'price_base_amount_in_tl')
dataset = dataset.drop(columns = 'price_type')
dataset = dataset.drop(columns = 'payment_option')
dataset = dataset.drop(columns = 'invoice_type')
dataset = dataset.drop(columns = 'tenant_signup_flow')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4662 entries, 4 to 21995
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   totalkgds                    4662 non-null   float64
#  1   pickup_city                  4662 non-null   object
#  2   dropoff_city                 4662 non-null   object
#  3   pickup_address_type          4662 non-null   object
#  4   dropoff_address_type         4662 non-null   object
#  5   category                     4662 non-null   object
#  6   vehicle_type                 4662 non-null   object
#  7   vehicle_body_type            4662 non-null   object
#  8   vehicle_package_type         4636 non-null   object
#  9   vehicle_way_of_loading       4662 non-null   object
#  10  vehicle_tonnage_per_vehicle  4662 non-null   float64
#  11  total_cost_amount_in_tl      4662 non-null   float64
#  12  usd_tl                       4662 non-null   float64
#  13  routes                       4662 non-null   object
#  14  km                           4662 non-null   float64
#  15  kursunsuz_v_max              4662 non-null   float64
#  16  pro_dizel                    4662 non-null   float64
# dtypes: float64(7), object(10)
# memory usage: 655.6+ KB

# %%
labelencoder = LabelEncoder()
dataset['category'] = labelencoder.fit_transform(dataset['category'])
dataset['vehicle_type'] = labelencoder.fit_transform(dataset['vehicle_type'])
dataset['vehicle_body_type'] = labelencoder.fit_transform(dataset['vehicle_body_type'])
dataset['vehicle_package_type'] = labelencoder.fit_transform(dataset['vehicle_package_type'])
dataset['vehicle_way_of_loading'] = labelencoder.fit_transform(dataset['vehicle_way_of_loading'])
dataset['pickup_address_type'] = labelencoder.fit_transform(dataset['pickup_address_type'])
dataset['dropoff_address_type'] = labelencoder.fit_transform(dataset['dropoff_address_type'])
dataset['routes'] = labelencoder.fit_transform(dataset['routes'])
dataset['pickup_city'] = labelencoder.fit_transform(dataset['pickup_city'])
dataset['dropoff_city'] = labelencoder.fit_transform(dataset['dropoff_city'])


dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4662 entries, 4 to 21995
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   totalkgds                    4662 non-null   float64
#  1   pickup_city                  4662 non-null   int64
#  2   dropoff_city                 4662 non-null   int64
#  3   pickup_address_type          4662 non-null   int64
#  4   dropoff_address_type         4662 non-null   int64
#  5   category                     4662 non-null   int64
#  6   vehicle_type                 4662 non-null   int64
#  7   vehicle_body_type            4662 non-null   int64
#  8   vehicle_package_type         4662 non-null   int64
#  9   vehicle_way_of_loading       4662 non-null   int64
#  10  vehicle_tonnage_per_vehicle  4662 non-null   float64
#  11  total_cost_amount_in_tl      4662 non-null   float64
#  12  usd_tl                       4662 non-null   float64
#  13  routes                       4662 non-null   int64
#  14  km                           4662 non-null   float64
#  15  kursunsuz_v_max              4662 non-null   float64
#  16  pro_dizel                    4662 non-null   float64
# dtypes: float64(7), int64(10)
# memory usage: 655.6 KB

# %%
max(dataset['total_cost_amount_in_tl'])
# Out:
# 14345.59

# %%
dataset['km_fuel'] = dataset.km*dataset.kursunsuz_v_max

# %%
drops = [ 'vehicle_way_of_loading','vehicle_tonnage_per_vehicle','usd_tl','category','dropoff_address_type','pickup_address_type','pro_dizel','routes','vehicle_type','pickup_city','dropoff_city']
dataset = dataset.drop(columns = drops)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.drop(columns = 'total_cost_amount_in_tl'), dataset.total_cost_amount_in_tl, test_size=0.3, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((3263, 6), (1399, 6))

# %%
model = xgb.XGBRegressor(eta = 0.121)

# %%
train = xgb.DMatrix(X_train, label = y_train )
test  = xgb.DMatrix(X_test, label = y_test)

# %%
model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              eta=0.121, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.120999999,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred = model.predict(X_train)

# %%
metrics.r2_score(y_train,y_pred)
# Out:
# 0.9877256012190856

# %%
plt.scatter(y_train,y_pred,color='blue',label='Prediction')
plt.scatter(y_train,y_train,color='red',label='Perfect prediction')

# %%
metrics.mean_absolute_error(y_train,y_pred)
# Out:
# 128.15506692056894

# %%
predictions = model.predict(X_test)

# %%
metrics.r2_score(predictions,y_test)
# Out:
# 0.9826313898349899

# %%
plt.scatter(y_test,predictions,color='blue',label='Prediction')
plt.scatter(y_test,y_test,color='red',label='Perfect prediction')

# %%
metrics.mean_absolute_error(predictions,y_test)
# Out:
# 147.07911572143468

# %%
X_train.columns
# Out:
# Index(['totalkgds', 'vehicle_body_type', 'vehicle_package_type', 'km',
#        'kursunsuz_v_max', 'km_fuel'],
#       dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.02875894, 0.0243202 , 0.10003275, 0.6336665 , 0.01382023,
#        0.19940133], dtype=float32)

# %%
mart_data = pd.read_csv('desktop/after_mart.csv')
mart_data
# Out:
#             id value_currency latest_status  \
# 0     PS6AP2DU            EUR      CANCELED
# 1     TC0KXIOZ            TRY      CANCELED
# 2     V1XPTCKS            TRY      APPROVED
# 3     5IYFNPZI            TRY      APPROVED
# 4     4SG39B9V            TRY      APPROVED
# ...        ...            ...           ...
# 2969  0E8F7OJA            TRY     DELIVERED
# 2970  72O60VFO            TRY     DELIVERED
# 2971  FVTWO3H9            TRY     DELIVERED
# 2972  L3J3ZFRU            TRY      CANCELED
# 2973  G2KKG2FL            TRY      CANCELED
#
#                                            shipper_note updatedby  \
# 0                                                   NaN       NaN
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4     5 palet ürünün bir kısmı sıvı sabun içermekte ...       NaN
# ...                                                 ...       ...
# 2969                                                NaN       NaN
# 2970                                                NaN       NaN
# 2971                                                NaN       NaN
# 2972                                                NaN       NaN
# 2973                  Tenteli kayar çatılı araç olmalı.       NaN
#
#                     updatedat                createdat  order_id  \
# 0     2022-02-11 11:14:41.602  2022-02-11 11:10:22.380       NaN
# 1     2022-02-17 13:55:37.242  2022-02-14 09:19:45.624       NaN
# 2     2022-03-22 14:36:17.740  2022-03-22 14:35:15.290       NaN
# 3     2022-03-22 15:01:34.210  2022-03-22 14:34:22.388       NaN
# 4     2022-03-22 08:01:37.467  2022-03-22 08:01:37.467       NaN
# ...                       ...                      ...       ...
# 2969  2022-03-01 06:19:46.626  2022-02-28 15:08:22.575       NaN
# 2970  2022-03-01 18:05:48.553  2022-02-28 14:25:43.604       NaN
# 2971  2022-03-01 19:14:49.124  2022-02-28 18:55:53.268       NaN
# 2972  2022-03-01 08:57:17.675  2022-03-01 08:47:28.507       NaN
# 2973  2022-03-01 07:04:37.679  2022-02-28 14:53:34.256  Y22-2427
#
#                     pricing_id  totalkgds  ... total_cost_amount  \
# 0     620643c46ecc56658317d86a     465.08  ...               NaN
# 1     620a1e7a9fa329591220165a    5907.50  ...               NaN
# 2     6239dea04849697c6e0395e3   24000.00  ...               NaN
# 3     6239de3f4849697c6e0395e2   24000.00  ...               NaN
# 4     6239826086b3135181bfed3f    4480.00  ...               NaN
# ...                        ...        ...  ...               ...
# 2969  621ce56566f1f50b18a4c192   15000.00  ...            1200.0
# 2970  621cdb6666f1f50b18a4c18f   15000.00  ...            1200.0
# 2971  621d1aad9e374a5f4f4d69ff    7500.00  ...             900.0
# 2972  621ddd9933905c2549688408     384.00  ...               NaN
# 2973  621ce1ed66f1f50b18a4c190   26000.00  ...               NaN
#
#      cost_currency total_cost_amount_in_tl total_cost_amount_in_eur  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
# ...            ...                     ...                      ...
# 2969           TRY                  1200.0                    77.00
# 2970           TRY                  1200.0                    77.42
# 2971           TRY                   900.0                    57.75
# 2972           NaN                     NaN                      NaN
# 2973           NaN                     NaN                      NaN
#
#      total_cost_amount_in_usd total_trip_cost_amount_in_tl  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 2969                    86.27                       1200.0
# 2970                    86.62                       1200.0
# 2971                    64.70                        900.0
# 2972                      NaN                          NaN
# 2973                      NaN                          NaN
#
#      total_trip_cost_amount_in_eur total_trip_cost_amount_in_usd  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 2969                         77.00                         86.27
# 2970                         77.42                         86.62
# 2971                         57.75                         64.70
# 2972                           NaN                           NaN
# 2973                           NaN                           NaN
#
#                  routes   km
# 0       İstanbul_Berlin  NaN
# 1      İstanbul_Antalya  NaN
# 2         Mersin_Styria  NaN
# 3       Mersin_İstanbul  NaN
# 4     İstanbul_Budapest  NaN
# ...                 ...  ...
# 2969  İstanbul_İstanbul  1.0
# 2970  İstanbul_İstanbul  1.0
# 2971  İstanbul_İstanbul  1.0
# 2972  İstanbul_İstanbul  1.0
# 2973    Kocaeli_Kütahya  NaN
#
# [2974 rows x 89 columns]

# %%
mart_data['Tarih']= mart_data.pickup_start_date.str[:-13]
mart_data['Tarih']
# Out:
# 0       2022-04-08
# 1       2022-04-01
# 2       2022-03-25
# 3       2022-03-25
# 4       2022-03-25
#            ...
# 2969    2022-03-01
# 2970    2022-03-01
# 2971    2022-03-01
# 2972    2022-03-01
# 2973    2022-03-01
# Name: Tarih, Length: 2974, dtype: object

# %%
mart_inner_join = pd.merge(mart_data, 
                      data, 
                      on ='Tarih', 
                      how ='inner')
mart_inner_join
# Out:
#             id value_currency latest_status  \
# 0     2GTL83V7            TRY     DELIVERED
# 1     2GTL83V7            TRY     DELIVERED
# 2     RG7WFKCL            TRY     DELIVERED
# 3     RG7WFKCL            TRY     DELIVERED
# 4     EWOKU7MY            TRY     DELIVERED
# ...        ...            ...           ...
# 2955  FVTWO3H9            TRY     DELIVERED
# 2956  L3J3ZFRU            TRY      CANCELED
# 2957  L3J3ZFRU            TRY      CANCELED
# 2958  G2KKG2FL            TRY      CANCELED
# 2959  G2KKG2FL            TRY      CANCELED
#
#                            shipper_note                 updatedby  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN  6213538de796e1460f92ab00
# 3                                   NaN  6213538de796e1460f92ab00
# 4                                   NaN  6213538de796e1460f92ab00
# ...                                 ...                       ...
# 2955                                NaN                       NaN
# 2956                                NaN                       NaN
# 2957                                NaN                       NaN
# 2958  Tenteli kayar çatılı araç olmalı.                       NaN
# 2959  Tenteli kayar çatılı araç olmalı.                       NaN
#
#                     updatedat                createdat    order_id  \
# 0     2022-03-16 14:48:16.970  2022-03-15 13:45:37.402  5183271464
# 1     2022-03-16 14:48:16.970  2022-03-15 13:45:37.402  5183271464
# 2     2022-03-22 11:21:48.734  2022-03-15 14:08:18.857  0040905679
# 3     2022-03-22 11:21:48.734  2022-03-15 14:08:18.857  0040905679
# 4     2022-03-22 11:21:48.734  2022-03-15 14:08:18.757  0040919088
# ...                       ...                      ...         ...
# 2955  2022-03-01 19:14:49.124  2022-02-28 18:55:53.268         NaN
# 2956  2022-03-01 08:57:17.675  2022-03-01 08:47:28.507         NaN
# 2957  2022-03-01 08:57:17.675  2022-03-01 08:47:28.507         NaN
# 2958  2022-03-01 07:04:37.679  2022-02-28 14:53:34.256    Y22-2427
# 2959  2022-03-01 07:04:37.679  2022-02-28 14:53:34.256    Y22-2427
#
#                     pricing_id  totalkgds  ... total_cost_amount_in_eur  \
# 0                          NaN    800.000  ...                    61.04
# 1                          NaN    800.000  ...                    61.04
# 2                          NaN     18.864  ...                     1.37
# 3                          NaN     18.864  ...                     1.37
# 4                          NaN     40.800  ...                     0.02
# ...                        ...        ...  ...                      ...
# 2955  621d1aad9e374a5f4f4d69ff   7500.000  ...                    57.75
# 2956  621ddd9933905c2549688408    384.000  ...                      NaN
# 2957  621ddd9933905c2549688408    384.000  ...                      NaN
# 2958  621ce1ed66f1f50b18a4c190  26000.000  ...                      NaN
# 2959  621ce1ed66f1f50b18a4c190  26000.000  ...                      NaN
#
#      total_cost_amount_in_usd total_trip_cost_amount_in_tl  \
# 0                       67.12                       991.75
# 1                       67.12                       991.75
# 2                        1.51                        22.32
# 3                        1.51                        22.32
# 4                        0.03                         0.37
# ...                       ...                          ...
# 2955                    64.70                       900.00
# 2956                      NaN                          NaN
# 2957                      NaN                          NaN
# 2958                      NaN                          NaN
# 2959                      NaN                          NaN
#
#      total_trip_cost_amount_in_eur total_trip_cost_amount_in_usd  \
# 0                            61.04                         67.12
# 1                            61.04                         67.12
# 2                             1.37                          1.51
# 3                             1.37                          1.51
# 4                             0.02                          0.03
# ...                            ...                           ...
# 2955                         57.75                         64.70
# 2956                           NaN                           NaN
# 2957                           NaN                           NaN
# 2958                           NaN                           NaN
# 2959                           NaN                           NaN
#
#                  routes    km       Tarih kursunsuz_v_max pro_dizel
# 0        İstanbul_Bursa   NaN  2022-03-15        20.38 TL  20.61 TL
# 1        İstanbul_Bursa   NaN  2022-03-15        20.38 TL  20.61 TL
# 2         Kocaeli_Bursa   NaN  2022-03-15        20.38 TL  20.61 TL
# 3         Kocaeli_Bursa   NaN  2022-03-15        20.38 TL  20.61 TL
# 4      Kocaeli_İstanbul  94.1  2022-03-15        20.38 TL  20.61 TL
# ...                 ...   ...         ...             ...       ...
# 2955  İstanbul_İstanbul   1.0  2022-03-01        16.53 TL  16.05 TL
# 2956  İstanbul_İstanbul   1.0  2022-03-01        16.53 TL  16.05 TL
# 2957  İstanbul_İstanbul   1.0  2022-03-01        16.53 TL  16.05 TL
# 2958    Kocaeli_Kütahya   NaN  2022-03-01        16.53 TL  16.05 TL
# 2959    Kocaeli_Kütahya   NaN  2022-03-01        16.53 TL  16.05 TL
#
# [2960 rows x 92 columns]

# %%
mart_inner_join=mart_inner_join.groupby('id').max()

# %%
mart_inner_join['kursunsuz_v_max'] = mart_inner_join['kursunsuz_v_max'].str[:-2]
mart_inner_join['kursunsuz_v_max']
# Out:
# id
# 01KA9MCP    17.42
# 02DTUCYM    16.53
# 02NQTAU5    20.38
# 031ZJED9    17.42
# 03WIAQH4    20.38
#              ...
# ZTWDFMCA    20.35
# ZTX5RTA2    16.53
# ZUYO3G05    20.38
# ZY2K6IS4    17.98
# ZYK4WYU8    16.53
# Name: kursunsuz_v_max, Length: 1480, dtype: object

# %%
mart_inner_join['pro_dizel'] = mart_inner_join['pro_dizel'].str[:-2]
mart_inner_join['pro_dizel']
# Out:
# id
# 01KA9MCP    17.56
# 02DTUCYM    16.05
# 02NQTAU5    22.86
# 031ZJED9    17.56
# 03WIAQH4    22.86
#              ...
# ZTWDFMCA    22.81
# ZTX5RTA2    16.05
# ZUYO3G05    22.86
# ZY2K6IS4    18.92
# ZYK4WYU8    16.06
# Name: pro_dizel, Length: 1480, dtype: object

# %%
mart_inner_join['pro_dizel'] = mart_inner_join.pro_dizel.astype(float)
mart_inner_join.kursunsuz_v_max = mart_inner_join.kursunsuz_v_max.astype(float)
mart_inner_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1480 entries, 01KA9MCP to ZYK4WYU8
# Data columns (total 91 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   value_currency                              1480 non-null   object
#  1   latest_status                               1480 non-null   object
#  2   shipper_note                                194 non-null    object
#  3   updatedby                                   246 non-null    object
#  4   updatedat                                   1480 non-null   object
#  5   createdat                                   1480 non-null   object
#  6   order_id                                    761 non-null    object
#  7   pricing_id                                  779 non-null    object
#  8   totalkgds                                   1480 non-null   float64
#  9   pickup_start_date                           1480 non-null   object
#  10  pickup_end_date                             1480 non-null   object
#  11  customer_representative_name                1475 non-null   object
#  12  customer_representative_id                  1475 non-null   object
#  13  pickup_district                             1479 non-null   object
#  14  pickup_company                              1480 non-null   object
#  15  pickup_city                                 1480 non-null   object
#  16  pickup_zipcode                              4 non-null      object
#  17  pickup_name                                 1480 non-null   object
#  18  pickup_address_type                         1480 non-null   object
#  19  pickup_country_id                           1480 non-null   object
#  20  dropoff_country_id                          1480 non-null   object
#  21  source_id                                   779 non-null    float64
#  22  category                                    1480 non-null   object
#  23  dropoff_district                            1436 non-null   object
#  24  dropoff_company                             1480 non-null   object
#  25  dropoff_city                                1480 non-null   object
#  26  dropoff_zipcode                             28 non-null     object
#  27  dropoff_name                                1480 non-null   object
#  28  dropoff_address_type                        1175 non-null   object
#  29  value                                       1480 non-null   float64
#  30  waybillnumber                               512 non-null    object
#  31  price_base_amount                           1450 non-null   float64
#  32  price_total_amount                          1450 non-null   float64
#  33  price_tax_amount                            1450 non-null   float64
#  34  price_currency                              1450 non-null   object
#  35  discount_status                             264 non-null    object
#  36  price_type                                  358 non-null    object
#  37  expected_delivery_date                      1450 non-null   object
#  38  shipment_type                               1480 non-null   object
#  39  vehicle_type                                643 non-null    object
#  40  vehicle_package_type                        568 non-null    object
#  41  vehicle_body_type                           643 non-null    object
#  42  vehicle_way_of_loading                      643 non-null    object
#  43  vehicle_tonnage_per_vehicle                 643 non-null    float64
#  44  approved_status_date                        1157 non-null   object
#  45  in_transit_status_date                      292 non-null    object
#  46  in_delivery_status_date                     761 non-null    object
#  47  in_arrival_crossdock_status_date            6 non-null      object
#  48  delivered_status_date                       1333 non-null   object
#  49  in_crossdock_status_date                    131 non-null    object
#  50  in_intermediate_transportation_status_date  0 non-null      float64
#  51  in_main_transportation_status_date          1 non-null      object
#  52  in_pickup_status_date                       644 non-null    object
#  53  tenant_id                                   1480 non-null   object
#  54  user_id                                     1480 non-null   object
#  55  latest_pod_status                           1480 non-null   object
#  56  latest_invoice_status                       1480 non-null   object
#  57  payment_status                              779 non-null    object
#  58  payment_id                                  0 non-null      float64
#  59  payment_option                              1480 non-null   object
#  60  invoice_type                                777 non-null    object
#  61  invoice_document_id                         777 non-null    object
#  62  invoice_id                                  0 non-null      float64
#  63  latest_status_desc_code                     125 non-null    object
#  64  title                                       1480 non-null   object
#  65  tenant_createat                             1480 non-null   object
#  66  tenant_type                                 1480 non-null   object
#  67  invoice_company_title                       1480 non-null   object
#  68  tenant_signup_flow                          1480 non-null   object
#  69  user_email                                  1480 non-null   object
#  70  user_role                                   1480 non-null   object
#  71  assigned_trip_count                         1348 non-null   float64
#  72  eur_tl                                      1480 non-null   float64
#  73  usd_tl                                      1480 non-null   float64
#  74  eur_usd                                     1480 non-null   float64
#  75  price_base_amount_in_tl                     1450 non-null   float64
#  76  price_base_amount_in_usd                    1450 non-null   float64
#  77  price_base_amount_in_eur                    1450 non-null   float64
#  78  total_cost_amount                           1349 non-null   float64
#  79  cost_currency                               1349 non-null   object
#  80  total_cost_amount_in_tl                     1349 non-null   float64
#  81  total_cost_amount_in_eur                    1349 non-null   float64
#  82  total_cost_amount_in_usd                    1349 non-null   float64
#  83  total_trip_cost_amount_in_tl                1349 non-null   float64
#  84  total_trip_cost_amount_in_eur               1349 non-null   float64
#  85  total_trip_cost_amount_in_usd               1349 non-null   float64
#  86  routes                                      1480 non-null   object
#  87  km                                          857 non-null    float64
#  88  Tarih                                       1480 non-null   object
#  89  kursunsuz_v_max                             1480 non-null   float64
#  90  pro_dizel                                   1480 non-null   float64
# dtypes: float64(27), object(64)
# memory usage: 1.1+ MB

# %%
mart_data = mart_inner_join
mart_data
# Out:
#          value_currency latest_status               shipper_note  \
# id
# 01KA9MCP            TRY     DELIVERED                        NaN
# 02DTUCYM            TRY     DELIVERED                        NaN
# 02NQTAU5            TRY     DELIVERED                        NaN
# 031ZJED9            TRY      CANCELED  Onay alınarak ilerlenecek
# 03WIAQH4            TRY      CANCELED                        NaN
# ...                 ...           ...                        ...
# ZTWDFMCA            TRY    IN_TRANSIT                        NaN
# ZTX5RTA2            TRY     DELIVERED                        NaN
# ZUYO3G05            TRY      CANCELED                        NaN
# ZY2K6IS4            TRY     DELIVERED                        NaN
# ZYK4WYU8            TRY     DELIVERED                        NaN
#
#                          updatedby                updatedat  \
# id
# 01KA9MCP                       NaN  2022-03-05 12:15:58.147
# 02DTUCYM  61485fe9ef31ce19fc2cc0da  2022-03-09 10:51:39.465
# 02NQTAU5                       NaN  2022-03-15 06:15:01.540
# 031ZJED9                       NaN  2022-03-04 06:51:33.313
# 03WIAQH4                       NaN  2022-03-07 10:07:08.634
# ...                            ...                      ...
# ZTWDFMCA                       NaN  2022-03-11 07:54:18.213
# ZTX5RTA2  61485fe9ef31ce19fc2cc0da  2022-03-09 10:51:39.465
# ZUYO3G05                       NaN  2022-03-07 10:07:08.634
# ZY2K6IS4                       NaN  2022-03-07 12:43:09.481
# ZYK4WYU8                       NaN  2022-03-10 19:27:07.739
#
#                         createdat    order_id                pricing_id  \
# id
# 01KA9MCP  2022-03-02 13:55:28.290         NaN  621f774fe8037570c4cc4888
# 02DTUCYM  2022-03-01 14:25:27.347  0040873083                       NaN
# 02NQTAU5  2022-03-10 11:38:40.446         NaN                       NaN
# 031ZJED9  2022-03-03 06:41:16.737         NaN  6220630382bdd701ade7f39b
# 03WIAQH4  2022-03-07 10:06:01.191         NaN  6225d907ed4bd061b222275b
# ...                           ...         ...                       ...
# ZTWDFMCA  2022-03-10 08:37:32.940         NaN  6229b8c9f75a5700ad5111f7
# ZTX5RTA2  2022-03-01 14:25:27.628  0040876608                       NaN
# ZUYO3G05  2022-03-07 10:06:01.191         NaN  6225d907ed4bd061b222275b
# ZY2K6IS4  2022-03-03 15:00:26.890         NaN  6220d7e6d034304033e3dd4d
# ZYK4WYU8  2022-03-01 20:20:35.122         NaN                       NaN
#
#           totalkgds        pickup_start_date  ... total_cost_amount_in_eur  \
# id                                            ...
# 01KA9MCP    8000.00  2022-03-03 05:00:00.000  ...                   480.74
# 02DTUCYM       1.80  2022-03-01 11:00:00.000  ...                     0.11
# 02NQTAU5     576.00  2022-03-11 06:00:00.000  ...                    33.12
# 031ZJED9   19000.00  2022-03-03 06:00:00.000  ...                      NaN
# 03WIAQH4   24000.00  2022-03-12 06:00:00.000  ...                      NaN
# ...             ...                      ...  ...                      ...
# ZTWDFMCA    5000.00  2022-03-10 06:00:00.000  ...                      NaN
# ZTX5RTA2      33.48  2022-03-01 11:00:00.000  ...                     0.02
# ZUYO3G05   24000.00  2022-03-12 06:00:00.000  ...                      NaN
# ZY2K6IS4   25000.00  2022-03-04 06:00:00.000  ...                   401.78
# ZYK4WYU8     576.00  2022-03-02 06:00:00.000  ...                    49.78
#
#          total_cost_amount_in_usd total_trip_cost_amount_in_tl  \
# id
# 01KA9MCP                   533.28                      7500.00
# 02DTUCYM                     0.12                         1.65
# 02NQTAU5                    36.58                       540.33
# 031ZJED9                      NaN                          NaN
# 03WIAQH4                      NaN                          NaN
# ...                           ...                          ...
# ZTWDFMCA                      NaN                          NaN
# ZTX5RTA2                     0.02                         0.28
# ZUYO3G05                      NaN                          NaN
# ZY2K6IS4                   445.63                      6300.00
# ZYK4WYU8                    55.23                       776.75
#
#          total_trip_cost_amount_in_eur total_trip_cost_amount_in_usd  \
# id
# 01KA9MCP                        480.74                        533.28
# 02DTUCYM                          0.11                          0.12
# 02NQTAU5                         33.12                         36.58
# 031ZJED9                           NaN                           NaN
# 03WIAQH4                           NaN                           NaN
# ...                                ...                           ...
# ZTWDFMCA                           NaN                           NaN
# ZTX5RTA2                          0.02                          0.02
# ZUYO3G05                           NaN                           NaN
# ZY2K6IS4                        401.78                        445.63
# ZYK4WYU8                         49.78                         55.23
#
#                     routes     km       Tarih kursunsuz_v_max pro_dizel
# id
# 01KA9MCP    Kocaeli_Mersin    NaN  2022-03-03           17.42     17.56
# 02DTUCYM     Kocaeli_Bursa    NaN  2022-03-01           16.53     16.05
# 02NQTAU5    Kocaeli_Ankara    NaN  2022-03-11           20.38     22.86
# 031ZJED9    Ankara_Sakarya    NaN  2022-03-03           17.42     17.56
# 03WIAQH4     Mersin_Styria    NaN  2022-03-12           20.38     22.86
# ...                    ...    ...         ...             ...       ...
# ZTWDFMCA   Kocaeli_Antalya    NaN  2022-03-10           20.35     22.81
# ZTX5RTA2  Kocaeli_İstanbul   94.1  2022-03-01           16.53     16.05
# ZUYO3G05     Mersin_Styria    NaN  2022-03-12           20.38     22.86
# ZY2K6IS4       Burdur_Bolu  566.4  2022-03-04           17.98     18.92
# ZYK4WYU8     Kocaeli_Bursa    NaN  2022-03-02           16.53     16.06
#
# [1480 rows x 91 columns]

# %%
mart_data = mart_data[mart_data.total_cost_amount_in_tl > 10]
mart_data = mart_data[mart_data.total_cost_amount_in_tl < 15000]

mart_data
# Out:
#          value_currency latest_status  shipper_note updatedby  \
# id
# 01KA9MCP            TRY     DELIVERED           NaN       NaN
# 02NQTAU5            TRY     DELIVERED           NaN       NaN
# 06KGX4F3            TRY     DELIVERED           NaN       NaN
# 06OXNBN0            TRY     DELIVERED           NaN       NaN
# 06P191MS            TRY     DELIVERED           NaN       NaN
# ...                 ...           ...           ...       ...
# ZQAVOC2C            TRY     DELIVERED  ADANA UĞRAMA       NaN
# ZRQPTNI7            TRY     DELIVERED            --       NaN
# ZSIQN046            TRY     DELIVERED           NaN       NaN
# ZY2K6IS4            TRY     DELIVERED           NaN       NaN
# ZYK4WYU8            TRY     DELIVERED           NaN       NaN
#
#                         updatedat                createdat    order_id  \
# id
# 01KA9MCP  2022-03-05 12:15:58.147  2022-03-02 13:55:28.290         NaN
# 02NQTAU5  2022-03-15 06:15:01.540  2022-03-10 11:38:40.446         NaN
# 06KGX4F3  2022-03-17 08:31:55.560  2022-03-14 12:47:10.978         NaN
# 06OXNBN0  2022-03-04 19:55:33.340  2022-03-04 07:19:02.666         NaN
# 06P191MS  2022-03-08 14:36:10.718  2022-03-08 14:31:19.463         NaN
# ...                           ...                      ...         ...
# ZQAVOC2C  2022-03-01 07:44:54.157  2022-03-01 06:57:57.343         NaN
# ZRQPTNI7  2022-03-15 19:18:13.826  2022-03-15 15:03:22.206           -
# ZSIQN046  2022-03-18 06:12:08.242  2022-03-15 12:33:43.560  5100245259
# ZY2K6IS4  2022-03-07 12:43:09.481  2022-03-03 15:00:26.890         NaN
# ZYK4WYU8  2022-03-10 19:27:07.739  2022-03-01 20:20:35.122         NaN
#
#                         pricing_id  totalkgds        pickup_start_date  ...  \
# id                                                                      ...
# 01KA9MCP  621f774fe8037570c4cc4888     8000.0  2022-03-03 05:00:00.000  ...
# 02NQTAU5                       NaN      576.0  2022-03-11 06:00:00.000  ...
# 06KGX4F3  622f394286d9120ac94a5ac3    25000.0  2022-03-15 06:00:00.000  ...
# 06OXNBN0  6221bd6309204a5ed8a4a43a    25000.0  2022-03-04 06:00:00.000  ...
# 06P191MS                       NaN      576.0  2022-03-09 06:00:00.000  ...
# ...                            ...        ...                      ...  ...
# ZQAVOC2C  621dc3efa982ab546511fb6b    10000.0  2022-03-01 06:00:00.000  ...
# ZRQPTNI7  6230aaae313dee7ca5ecde8e    10000.0  2022-03-15 11:00:00.000  ...
# ZSIQN046                       NaN     2323.2  2022-03-15 06:00:00.000  ...
# ZY2K6IS4  6220d7e6d034304033e3dd4d    25000.0  2022-03-04 06:00:00.000  ...
# ZYK4WYU8                       NaN      576.0  2022-03-02 06:00:00.000  ...
#
#          total_cost_amount_in_eur total_cost_amount_in_usd  \
# id
# 01KA9MCP                   480.74                   533.28
# 02NQTAU5                    33.12                    36.58
# 06KGX4F3                   430.87                   473.71
# 06OXNBN0                   149.87                   166.23
# 06P191MS                    20.17                    21.95
# ...                           ...                      ...
# ZQAVOC2C                   545.45                   611.05
# ZRQPTNI7                   387.78                   426.34
# ZSIQN046                   266.29                   292.62
# ZY2K6IS4                   401.78                   445.63
# ZYK4WYU8                    49.78                    55.23
#
#          total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# id
# 01KA9MCP                      7500.00                        480.74
# 02NQTAU5                       540.33                         33.12
# 06KGX4F3                      7000.00                        430.87
# 06OXNBN0                      2350.00                        149.87
# 06P191MS                       318.25                         20.17
# ...                               ...                           ...
# ZQAVOC2C                      8500.00                        545.45
# ZRQPTNI7                      6300.00                        387.78
# ZSIQN046                      4304.09                        266.29
# ZY2K6IS4                      6300.00                        401.78
# ZYK4WYU8                       776.75                         49.78
#
#          total_trip_cost_amount_in_usd             routes     km       Tarih  \
# id
# 01KA9MCP                        533.28     Kocaeli_Mersin    NaN  2022-03-03
# 02NQTAU5                         36.58     Kocaeli_Ankara    NaN  2022-03-11
# 06KGX4F3                        473.71        Burdur_Bolu  566.4  2022-03-15
# 06OXNBN0                        166.23      Bursa_Kocaeli  132.4  2022-03-04
# 06P191MS                         21.95     Kocaeli_Manisa    NaN  2022-03-09
# ...                                ...                ...    ...         ...
# ZQAVOC2C                        611.05  Kocaeli_Gaziantep    NaN  2022-03-01
# ZRQPTNI7                        426.34     İstanbul_İzmir  479.0  2022-03-15
# ZSIQN046                        292.62     İstanbul_Bursa    NaN  2022-03-15
# ZY2K6IS4                        445.63        Burdur_Bolu  566.4  2022-03-04
# ZYK4WYU8                         55.23      Kocaeli_Bursa    NaN  2022-03-02
#
#          kursunsuz_v_max pro_dizel
# id
# 01KA9MCP           17.42     17.56
# 02NQTAU5           20.38     22.86
# 06KGX4F3           20.38     20.61
# 06OXNBN0           17.98     18.92
# 06P191MS           20.35     22.81
# ...                  ...       ...
# ZQAVOC2C           16.53     16.05
# ZRQPTNI7           20.38     20.61
# ZSIQN046           20.38     20.61
# ZY2K6IS4           17.98     18.92
# ZYK4WYU8           16.53     16.06
#
# [1056 rows x 91 columns]

# %%
# Get Delivered Shipments
accepted = (['DELIVERED'])

mart_data = mart_data[mart_data.latest_status.isin(accepted)]
mart_data
# Out:
#          value_currency latest_status  shipper_note updatedby  \
# id
# 01KA9MCP            TRY     DELIVERED           NaN       NaN
# 02NQTAU5            TRY     DELIVERED           NaN       NaN
# 06KGX4F3            TRY     DELIVERED           NaN       NaN
# 06OXNBN0            TRY     DELIVERED           NaN       NaN
# 06P191MS            TRY     DELIVERED           NaN       NaN
# ...                 ...           ...           ...       ...
# ZQAVOC2C            TRY     DELIVERED  ADANA UĞRAMA       NaN
# ZRQPTNI7            TRY     DELIVERED            --       NaN
# ZSIQN046            TRY     DELIVERED           NaN       NaN
# ZY2K6IS4            TRY     DELIVERED           NaN       NaN
# ZYK4WYU8            TRY     DELIVERED           NaN       NaN
#
#                         updatedat                createdat    order_id  \
# id
# 01KA9MCP  2022-03-05 12:15:58.147  2022-03-02 13:55:28.290         NaN
# 02NQTAU5  2022-03-15 06:15:01.540  2022-03-10 11:38:40.446         NaN
# 06KGX4F3  2022-03-17 08:31:55.560  2022-03-14 12:47:10.978         NaN
# 06OXNBN0  2022-03-04 19:55:33.340  2022-03-04 07:19:02.666         NaN
# 06P191MS  2022-03-08 14:36:10.718  2022-03-08 14:31:19.463         NaN
# ...                           ...                      ...         ...
# ZQAVOC2C  2022-03-01 07:44:54.157  2022-03-01 06:57:57.343         NaN
# ZRQPTNI7  2022-03-15 19:18:13.826  2022-03-15 15:03:22.206           -
# ZSIQN046  2022-03-18 06:12:08.242  2022-03-15 12:33:43.560  5100245259
# ZY2K6IS4  2022-03-07 12:43:09.481  2022-03-03 15:00:26.890         NaN
# ZYK4WYU8  2022-03-10 19:27:07.739  2022-03-01 20:20:35.122         NaN
#
#                         pricing_id  totalkgds        pickup_start_date  ...  \
# id                                                                      ...
# 01KA9MCP  621f774fe8037570c4cc4888     8000.0  2022-03-03 05:00:00.000  ...
# 02NQTAU5                       NaN      576.0  2022-03-11 06:00:00.000  ...
# 06KGX4F3  622f394286d9120ac94a5ac3    25000.0  2022-03-15 06:00:00.000  ...
# 06OXNBN0  6221bd6309204a5ed8a4a43a    25000.0  2022-03-04 06:00:00.000  ...
# 06P191MS                       NaN      576.0  2022-03-09 06:00:00.000  ...
# ...                            ...        ...                      ...  ...
# ZQAVOC2C  621dc3efa982ab546511fb6b    10000.0  2022-03-01 06:00:00.000  ...
# ZRQPTNI7  6230aaae313dee7ca5ecde8e    10000.0  2022-03-15 11:00:00.000  ...
# ZSIQN046                       NaN     2323.2  2022-03-15 06:00:00.000  ...
# ZY2K6IS4  6220d7e6d034304033e3dd4d    25000.0  2022-03-04 06:00:00.000  ...
# ZYK4WYU8                       NaN      576.0  2022-03-02 06:00:00.000  ...
#
#          total_cost_amount_in_eur total_cost_amount_in_usd  \
# id
# 01KA9MCP                   480.74                   533.28
# 02NQTAU5                    33.12                    36.58
# 06KGX4F3                   430.87                   473.71
# 06OXNBN0                   149.87                   166.23
# 06P191MS                    20.17                    21.95
# ...                           ...                      ...
# ZQAVOC2C                   545.45                   611.05
# ZRQPTNI7                   387.78                   426.34
# ZSIQN046                   266.29                   292.62
# ZY2K6IS4                   401.78                   445.63
# ZYK4WYU8                    49.78                    55.23
#
#          total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# id
# 01KA9MCP                      7500.00                        480.74
# 02NQTAU5                       540.33                         33.12
# 06KGX4F3                      7000.00                        430.87
# 06OXNBN0                      2350.00                        149.87
# 06P191MS                       318.25                         20.17
# ...                               ...                           ...
# ZQAVOC2C                      8500.00                        545.45
# ZRQPTNI7                      6300.00                        387.78
# ZSIQN046                      4304.09                        266.29
# ZY2K6IS4                      6300.00                        401.78
# ZYK4WYU8                       776.75                         49.78
#
#          total_trip_cost_amount_in_usd             routes     km       Tarih  \
# id
# 01KA9MCP                        533.28     Kocaeli_Mersin    NaN  2022-03-03
# 02NQTAU5                         36.58     Kocaeli_Ankara    NaN  2022-03-11
# 06KGX4F3                        473.71        Burdur_Bolu  566.4  2022-03-15
# 06OXNBN0                        166.23      Bursa_Kocaeli  132.4  2022-03-04
# 06P191MS                         21.95     Kocaeli_Manisa    NaN  2022-03-09
# ...                                ...                ...    ...         ...
# ZQAVOC2C                        611.05  Kocaeli_Gaziantep    NaN  2022-03-01
# ZRQPTNI7                        426.34     İstanbul_İzmir  479.0  2022-03-15
# ZSIQN046                        292.62     İstanbul_Bursa    NaN  2022-03-15
# ZY2K6IS4                        445.63        Burdur_Bolu  566.4  2022-03-04
# ZYK4WYU8                         55.23      Kocaeli_Bursa    NaN  2022-03-02
#
#          kursunsuz_v_max pro_dizel
# id
# 01KA9MCP           17.42     17.56
# 02NQTAU5           20.38     22.86
# 06KGX4F3           20.38     20.61
# 06OXNBN0           17.98     18.92
# 06P191MS           20.35     22.81
# ...                  ...       ...
# ZQAVOC2C           16.53     16.05
# ZRQPTNI7           20.38     20.61
# ZSIQN046           20.38     20.61
# ZY2K6IS4           17.98     18.92
# ZYK4WYU8           16.53     16.06
#
# [1045 rows x 91 columns]

# %%
mart_data = mart_data[mart_data.routes.isin(routes)]
mart_data
# Out:
#          value_currency latest_status             shipper_note updatedby  \
# id
# 06KGX4F3            TRY     DELIVERED                      NaN       NaN
# 06OXNBN0            TRY     DELIVERED                      NaN       NaN
# 08WH8WLP            TRY     DELIVERED                      NaN       NaN
# 08XFCSA4            TRY     DELIVERED                      NaN       NaN
# 09XVIHN0            TRY     DELIVERED                      NaN       NaN
# ...                 ...           ...                      ...       ...
# ZNP212WL            TRY     DELIVERED                      NaN       NaN
# ZO9T1PZZ            TRY     DELIVERED  11257051901,11257051902       NaN
# ZOMSK235            TRY     DELIVERED                      NaN       NaN
# ZRQPTNI7            TRY     DELIVERED                       --       NaN
# ZY2K6IS4            TRY     DELIVERED                      NaN       NaN
#
#                         updatedat                createdat  \
# id
# 06KGX4F3  2022-03-17 08:31:55.560  2022-03-14 12:47:10.978
# 06OXNBN0  2022-03-04 19:55:33.340  2022-03-04 07:19:02.666
# 08WH8WLP  2022-03-05 21:16:07.408  2022-03-05 06:27:48.366
# 08XFCSA4  2022-03-12 05:32:31.456  2022-03-11 06:34:30.399
# 09XVIHN0  2022-03-10 19:34:44.158  2022-03-03 12:43:53.800
# ...                           ...                      ...
# ZNP212WL  2022-03-09 15:43:03.850  2022-03-04 14:02:03.414
# ZO9T1PZZ  2022-03-10 14:28:55.380  2022-03-10 07:43:46.282
# ZOMSK235  2022-03-09 15:43:03.850  2022-03-02 06:54:35.178
# ZRQPTNI7  2022-03-15 19:18:13.826  2022-03-15 15:03:22.206
# ZY2K6IS4  2022-03-07 12:43:09.481  2022-03-03 15:00:26.890
#
#                          order_id                pricing_id  totalkgds  \
# id
# 06KGX4F3                      NaN  622f394286d9120ac94a5ac3    25000.0
# 06OXNBN0                      NaN  6221bd6309204a5ed8a4a43a    25000.0
# 08WH8WLP                      NaN  622302d8d6e9721bd113bfc6    25000.0
# 08XFCSA4                      NaN  622aed6e8d60f94ffb9b33be    25000.0
# 09XVIHN0               5100244865                       NaN      432.0
# ...                           ...                       ...        ...
# ZNP212WL               5183253875                       NaN      160.0
# ZO9T1PZZ  11257051901,11257051902  6229ac23c8d15c2990644120      480.0
# ZOMSK235               5183248527                       NaN      224.0
# ZRQPTNI7                        -  6230aaae313dee7ca5ecde8e    10000.0
# ZY2K6IS4                      NaN  6220d7e6d034304033e3dd4d    25000.0
#
#                 pickup_start_date  ... total_cost_amount_in_eur  \
# id                                 ...
# 06KGX4F3  2022-03-15 06:00:00.000  ...                   430.87
# 06OXNBN0  2022-03-04 06:00:00.000  ...                   149.87
# 08WH8WLP  2022-03-05 06:00:00.000  ...                   153.06
# 08XFCSA4  2022-03-11 11:00:00.000  ...                   159.38
# 09XVIHN0  2022-03-03 06:00:00.000  ...                    52.25
# ...                           ...  ...                      ...
# ZNP212WL  2022-03-04 11:00:00.000  ...                     7.52
# ZO9T1PZZ  2022-03-10 06:00:00.000  ...                    28.20
# ZOMSK235  2022-03-02 11:00:00.000  ...                     3.54
# ZRQPTNI7  2022-03-15 11:00:00.000  ...                   387.78
# ZY2K6IS4  2022-03-04 06:00:00.000  ...                   401.78
#
#          total_cost_amount_in_usd total_trip_cost_amount_in_tl  \
# id
# 06KGX4F3                   473.71                      7000.00
# 06OXNBN0                   166.23                      2350.00
# 08WH8WLP                   169.76                      2400.00
# 08XFCSA4                   176.03                      2600.00
# 09XVIHN0                    57.95                       819.28
# ...                           ...                          ...
# ZNP212WL                     8.34                       117.82
# ZO9T1PZZ                    31.14                       460.00
# ZOMSK235                     3.93                        55.24
# ZRQPTNI7                   426.34                      6300.00
# ZY2K6IS4                   445.63                      6300.00
#
#          total_trip_cost_amount_in_eur total_trip_cost_amount_in_usd  \
# id
# 06KGX4F3                        430.87                        473.71
# 06OXNBN0                        149.87                        166.23
# 08WH8WLP                        153.06                        169.76
# 08XFCSA4                        159.38                        176.03
# 09XVIHN0                         52.25                         57.95
# ...                                ...                           ...
# ZNP212WL                          7.52                          8.34
# ZO9T1PZZ                         28.20                         31.14
# ZOMSK235                          3.54                          3.93
# ZRQPTNI7                        387.78                        426.34
# ZY2K6IS4                        401.78                        445.63
#
#                    routes     km       Tarih kursunsuz_v_max pro_dizel
# id
# 06KGX4F3      Burdur_Bolu  566.4  2022-03-15           20.38     20.61
# 06OXNBN0    Bursa_Kocaeli  132.4  2022-03-04           17.98     18.92
# 08WH8WLP    Bursa_Kocaeli  132.4  2022-03-05           18.69     19.77
# 08XFCSA4    Bursa_Kocaeli  132.4  2022-03-11           20.38     22.86
# 09XVIHN0   İstanbul_İzmir  479.0  2022-03-03           17.42     17.56
# ...                   ...    ...         ...             ...       ...
# ZNP212WL  İstanbul_Ankara  443.9  2022-03-04           17.98     18.92
# ZO9T1PZZ    Kocaeli_İzmir  461.8  2022-03-10           20.35     22.81
# ZOMSK235   İstanbul_İzmir  479.0  2022-03-02           16.53     16.06
# ZRQPTNI7   İstanbul_İzmir  479.0  2022-03-15           20.38     20.61
# ZY2K6IS4      Burdur_Bolu  566.4  2022-03-04           17.98     18.92
#
# [537 rows x 91 columns]

# %%
#Split Data by Shipment Type
mart_data = mart_data[mart_data.shipment_type == 'FTL']
orj_mart_data = mart_data
mart_data
# Out:
#          value_currency latest_status shipper_note updatedby  \
# id
# 06KGX4F3            TRY     DELIVERED          NaN       NaN
# 06OXNBN0            TRY     DELIVERED          NaN       NaN
# 08WH8WLP            TRY     DELIVERED          NaN       NaN
# 08XFCSA4            TRY     DELIVERED          NaN       NaN
# 0A2OCHU5            TRY     DELIVERED          NaN       NaN
# ...                 ...           ...          ...       ...
# Z6M54G3W            TRY     DELIVERED          NaN       NaN
# ZE9K9XL5            TRY     DELIVERED          NaN       NaN
# ZF0KY8KM            TRY     DELIVERED          NaN       NaN
# ZRQPTNI7            TRY     DELIVERED           --       NaN
# ZY2K6IS4            TRY     DELIVERED          NaN       NaN
#
#                         updatedat                createdat order_id  \
# id
# 06KGX4F3  2022-03-17 08:31:55.560  2022-03-14 12:47:10.978      NaN
# 06OXNBN0  2022-03-04 19:55:33.340  2022-03-04 07:19:02.666      NaN
# 08WH8WLP  2022-03-05 21:16:07.408  2022-03-05 06:27:48.366      NaN
# 08XFCSA4  2022-03-12 05:32:31.456  2022-03-11 06:34:30.399      NaN
# 0A2OCHU5  2022-03-15 15:00:30.193  2022-03-15 11:21:58.719      NaN
# ...                           ...                      ...      ...
# Z6M54G3W  2022-03-12 07:46:48.422  2022-03-12 07:15:30.000      NaN
# ZE9K9XL5  2022-03-08 07:12:02.403  2022-03-05 07:55:33.000     9002
# ZF0KY8KM  2022-03-04 08:35:50.106  2022-03-02 09:24:18.000     1013
# ZRQPTNI7  2022-03-15 19:18:13.826  2022-03-15 15:03:22.206        -
# ZY2K6IS4  2022-03-07 12:43:09.481  2022-03-03 15:00:26.890      NaN
#
#                         pricing_id  totalkgds        pickup_start_date  ...  \
# id                                                                      ...
# 06KGX4F3  622f394286d9120ac94a5ac3    25000.0  2022-03-15 06:00:00.000  ...
# 06OXNBN0  6221bd6309204a5ed8a4a43a    25000.0  2022-03-04 06:00:00.000  ...
# 08WH8WLP  622302d8d6e9721bd113bfc6    25000.0  2022-03-05 06:00:00.000  ...
# 08XFCSA4  622aed6e8d60f94ffb9b33be    25000.0  2022-03-11 11:00:00.000  ...
# 0A2OCHU5  623076d3038bae395aa3e615    25000.0  2022-03-15 06:00:00.000  ...
# ...                            ...        ...                      ...  ...
# Z6M54G3W                       NaN    25152.0  2022-03-12 09:00:00.000  ...
# ZE9K9XL5                       NaN    25000.0  2022-03-08 09:00:00.000  ...
# ZF0KY8KM                       NaN    13740.0  2022-03-03 09:00:00.000  ...
# ZRQPTNI7  6230aaae313dee7ca5ecde8e    10000.0  2022-03-15 11:00:00.000  ...
# ZY2K6IS4  6220d7e6d034304033e3dd4d    25000.0  2022-03-04 06:00:00.000  ...
#
#          total_cost_amount_in_eur total_cost_amount_in_usd  \
# id
# 06KGX4F3                   430.87                   473.71
# 06OXNBN0                   149.87                   166.23
# 08WH8WLP                   153.06                   169.76
# 08XFCSA4                   159.38                   176.03
# 0A2OCHU5                   153.88                   169.18
# ...                           ...                      ...
# Z6M54G3W                    88.88                    98.17
# ZE9K9XL5                   427.79                   465.55
# ZF0KY8KM                    96.15                   106.66
# ZRQPTNI7                   387.78                   426.34
# ZY2K6IS4                   401.78                   445.63
#
#          total_trip_cost_amount_in_tl total_trip_cost_amount_in_eur  \
# id
# 06KGX4F3                       7000.0                        430.87
# 06OXNBN0                       2350.0                        149.87
# 08WH8WLP                       2400.0                        153.06
# 08XFCSA4                       2600.0                        159.38
# 0A2OCHU5                       2500.0                        153.88
# ...                               ...                           ...
# Z6M54G3W                       1450.0                         88.88
# ZE9K9XL5                       6750.0                        427.79
# ZF0KY8KM                       1500.0                         96.15
# ZRQPTNI7                       6300.0                        387.78
# ZY2K6IS4                       6300.0                        401.78
#
#          total_trip_cost_amount_in_usd            routes     km       Tarih  \
# id
# 06KGX4F3                        473.71       Burdur_Bolu  566.4  2022-03-15
# 06OXNBN0                        166.23     Bursa_Kocaeli  132.4  2022-03-04
# 08WH8WLP                        169.76     Bursa_Kocaeli  132.4  2022-03-05
# 08XFCSA4                        176.03     Bursa_Kocaeli  132.4  2022-03-11
# 0A2OCHU5                        169.18     Bursa_Kocaeli  132.4  2022-03-15
# ...                                ...               ...    ...         ...
# Z6M54G3W                         98.17   Kocaeli_Kocaeli    1.0  2022-03-12
# ZE9K9XL5                        465.55     Kocaeli_İzmir  461.8  2022-03-08
# ZF0KY8KM                        106.66  Kocaeli_İstanbul   94.1  2022-03-03
# ZRQPTNI7                        426.34    İstanbul_İzmir  479.0  2022-03-15
# ZY2K6IS4                        445.63       Burdur_Bolu  566.4  2022-03-04
#
#          kursunsuz_v_max pro_dizel
# id
# 06KGX4F3           20.38     20.61
# 06OXNBN0           17.98     18.92
# 08WH8WLP           18.69     19.77
# 08XFCSA4           20.38     22.86
# 0A2OCHU5           20.38     20.61
# ...                  ...       ...
# Z6M54G3W           20.38     22.86
# ZE9K9XL5           19.27     21.22
# ZF0KY8KM           17.42     17.56
# ZRQPTNI7           20.38     20.61
# ZY2K6IS4           17.98     18.92
#
# [330 rows x 91 columns]

# %%
mart_data = pd.concat([mart_data['latest_status'],mart_data['totalkgds'],mart_data['pickup_city'],mart_data['dropoff_city'] ,mart_data['pickup_address_type'], mart_data['dropoff_address_type'],
                  mart_data['category'], mart_data['price_type'], 
                  mart_data['shipment_type'], mart_data['vehicle_type'],mart_data['vehicle_body_type'],
                  mart_data['vehicle_package_type'], mart_data['vehicle_way_of_loading'],
                  mart_data['vehicle_tonnage_per_vehicle'],mart_data['payment_option'],
                  mart_data['invoice_type'], mart_data['tenant_signup_flow'], 
                  mart_data['total_cost_amount_in_tl'], mart_data['usd_tl'],
                  mart_data['price_base_amount_in_tl']
                 ,mart_data['routes'],mart_data['km'],mart_data['kursunsuz_v_max'],mart_data['pro_dizel']], axis = 1)
mart_data
# Out:
#          latest_status  totalkgds pickup_city dropoff_city  \
# id
# 06KGX4F3     DELIVERED    25000.0      Burdur         Bolu
# 06OXNBN0     DELIVERED    25000.0       Bursa      Kocaeli
# 08WH8WLP     DELIVERED    25000.0       Bursa      Kocaeli
# 08XFCSA4     DELIVERED    25000.0       Bursa      Kocaeli
# 0A2OCHU5     DELIVERED    25000.0       Bursa      Kocaeli
# ...                ...        ...         ...          ...
# Z6M54G3W     DELIVERED    25152.0     Kocaeli      Kocaeli
# ZE9K9XL5     DELIVERED    25000.0     Kocaeli        İzmir
# ZF0KY8KM     DELIVERED    13740.0     Kocaeli     İstanbul
# ZRQPTNI7     DELIVERED    10000.0    İstanbul        İzmir
# ZY2K6IS4     DELIVERED    25000.0      Burdur         Bolu
#
#          pickup_address_type dropoff_address_type  category price_type  \
# id
# 06KGX4F3             FACTORY              FACTORY  DRY_FOOD        NaN
# 06OXNBN0             FACTORY            WAREHOUSE     BUILD        NaN
# 08WH8WLP             FACTORY            WAREHOUSE     BUILD        NaN
# 08XFCSA4             FACTORY            WAREHOUSE     OTHER        NaN
# 0A2OCHU5             FACTORY            WAREHOUSE     BUILD        NaN
# ...                      ...                  ...       ...        ...
# Z6M54G3W           WAREHOUSE            WAREHOUSE  DRY_FOOD        NaN
# ZE9K9XL5           WAREHOUSE                 MALL     OTHER        NaN
# ZF0KY8KM           WAREHOUSE                 MALL  DRY_FOOD        NaN
# ZRQPTNI7           WAREHOUSE                OTHER     OTHER       SPOT
# ZY2K6IS4             FACTORY              FACTORY  DRY_FOOD        NaN
#
#          shipment_type vehicle_type  ... payment_option invoice_type  \
# id                                   ...
# 06KGX4F3           FTL   SEMI_TRUCK  ...      PAY_LATER          NaN
# 06OXNBN0           FTL   SEMI_TRUCK  ...      PAY_LATER          NaN
# 08WH8WLP           FTL   SEMI_TRUCK  ...      PAY_LATER          NaN
# 08XFCSA4           FTL   SEMI_TRUCK  ...      PAY_LATER    E_INVOICE
# 0A2OCHU5           FTL   SEMI_TRUCK  ...      PAY_LATER          NaN
# ...                ...          ...  ...            ...          ...
# Z6M54G3W           FTL   SEMI_TRUCK  ...      PAY_LATER          NaN
# ZE9K9XL5           FTL   SEMI_TRUCK  ...      PAY_LATER          NaN
# ZF0KY8KM           FTL  _10_WHEELER  ...      PAY_LATER          NaN
# ZRQPTNI7           FTL   SEMI_TRUCK  ...      PAY_LATER          NaN
# ZY2K6IS4           FTL   SEMI_TRUCK  ...      PAY_LATER          NaN
#
#          tenant_signup_flow  total_cost_amount_in_tl   usd_tl  \
# id
# 06KGX4F3        SELF_SIGNUP                   7000.0  14.7769
# 06OXNBN0        SELF_SIGNUP                   2350.0  14.1374
# 08WH8WLP        SELF_SIGNUP                   2400.0  14.1374
# 08XFCSA4        SELF_SIGNUP                   2600.0  14.7700
# 0A2OCHU5        SELF_SIGNUP                   2500.0  14.7769
# ...                     ...                      ...      ...
# Z6M54G3W        SELF_SIGNUP                   1450.0  14.7700
# ZE9K9XL5        SELF_SIGNUP                   6750.0  14.4989
# ZF0KY8KM        SELF_SIGNUP                   1500.0  14.1374
# ZRQPTNI7        SELF_SIGNUP                   6300.0  14.7769
# ZY2K6IS4        SELF_SIGNUP                   6300.0  14.1374
#
#          price_base_amount_in_tl            routes     km  kursunsuz_v_max  \
# id
# 06KGX4F3                 7142.31       Burdur_Bolu  566.4            20.38
# 06OXNBN0                 2550.00     Bursa_Kocaeli  132.4            17.98
# 08WH8WLP                 2550.00     Bursa_Kocaeli  132.4            18.69
# 08XFCSA4                 2726.00     Bursa_Kocaeli  132.4            20.38
# 0A2OCHU5                 2622.00     Bursa_Kocaeli  132.4            20.38
# ...                          ...               ...    ...              ...
# Z6M54G3W                 1614.88   Kocaeli_Kocaeli    1.0            20.38
# ZE9K9XL5                 5569.13     Kocaeli_İzmir  461.8            19.27
# ZF0KY8KM                 1198.29  Kocaeli_İstanbul   94.1            17.42
# ZRQPTNI7                 5259.00    İstanbul_İzmir  479.0            20.38
# ZY2K6IS4                 6838.00       Burdur_Bolu  566.4            17.98
#
#           pro_dizel
# id
# 06KGX4F3      20.61
# 06OXNBN0      18.92
# 08WH8WLP      19.77
# 08XFCSA4      22.86
# 0A2OCHU5      20.61
# ...             ...
# Z6M54G3W      22.86
# ZE9K9XL5      21.22
# ZF0KY8KM      17.56
# ZRQPTNI7      20.61
# ZY2K6IS4      18.92
#
# [330 rows x 24 columns]

# %%
mart_data = mart_data.drop(columns = 'shipment_type')
mart_data = mart_data.drop(columns = 'latest_status')
mart_data = mart_data.drop(columns = 'price_base_amount_in_tl')
mart_data = mart_data.drop(columns = 'price_type')
mart_data = mart_data.drop(columns = 'payment_option')
mart_data = mart_data.drop(columns = 'invoice_type')
mart_data = mart_data.drop(columns = 'tenant_signup_flow')

# %%
mart_data['km_fuel'] = mart_data.km*mart_data.kursunsuz_v_max

# %%
new_data = mart_data.drop(columns = drops)
new_data.columns
# Out:
# Index(['totalkgds', 'vehicle_body_type', 'vehicle_package_type',
#        'total_cost_amount_in_tl', 'km', 'kursunsuz_v_max', 'km_fuel'],
#       dtype='object')

# %%
labelencoder = LabelEncoder()
mart_data['category'] = labelencoder.fit_transform(mart_data['category'])
mart_data['vehicle_type'] = labelencoder.fit_transform(mart_data['vehicle_type'])
mart_data['vehicle_body_type'] = labelencoder.fit_transform(mart_data['vehicle_body_type'])
mart_data['vehicle_package_type'] = labelencoder.fit_transform(mart_data['vehicle_package_type'])
mart_data['vehicle_way_of_loading'] = labelencoder.fit_transform(mart_data['vehicle_way_of_loading'])
mart_data['pickup_address_type'] = labelencoder.fit_transform(mart_data['pickup_address_type'])
mart_data['dropoff_address_type'] = labelencoder.fit_transform(mart_data['dropoff_address_type'])
mart_data['routes'] = labelencoder.fit_transform(mart_data['routes'])
mart_data['pickup_city'] = labelencoder.fit_transform(mart_data['pickup_city'])
mart_data['dropoff_city'] = labelencoder.fit_transform(mart_data['dropoff_city'])


mart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, 06KGX4F3 to ZY2K6IS4
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   totalkgds                    330 non-null    float64
#  1   pickup_city                  330 non-null    int64
#  2   dropoff_city                 330 non-null    int64
#  3   pickup_address_type          330 non-null    int64
#  4   dropoff_address_type         330 non-null    int64
#  5   category                     330 non-null    int64
#  6   vehicle_type                 330 non-null    int64
#  7   vehicle_body_type            330 non-null    int64
#  8   vehicle_package_type         330 non-null    int64
#  9   vehicle_way_of_loading       330 non-null    int64
#  10  vehicle_tonnage_per_vehicle  330 non-null    float64
#  11  total_cost_amount_in_tl      330 non-null    float64
#  12  usd_tl                       330 non-null    float64
#  13  routes                       330 non-null    int64
#  14  km                           330 non-null    float64
#  15  kursunsuz_v_max              330 non-null    float64
#  16  pro_dizel                    330 non-null    float64
#  17  km_fuel                      330 non-null    float64
# dtypes: float64(8), int64(10)
# memory usage: 49.0+ KB

# %%
mart_data = mart_data.drop(columns = drops)
mart_data.columns
# Out:
# Index(['totalkgds', 'vehicle_body_type', 'vehicle_package_type',
#        'total_cost_amount_in_tl', 'km', 'kursunsuz_v_max', 'km_fuel'],
#       dtype='object')

# %%
mart_predict= model.predict(mart_data.drop(columns = ['total_cost_amount_in_tl']))

# %%
metrics.r2_score(mart_data.total_cost_amount_in_tl,mart_predict)
# Out:
# 0.8790055809819349

# %%
plt.scatter(mart_data.total_cost_amount_in_tl,mart_predict,color='blue',label='Prediction')
plt.scatter(mart_data.total_cost_amount_in_tl,mart_data.total_cost_amount_in_tl,color='red',label='Perfect prediction')

# %%
metrics.mean_absolute_error(mart_data.total_cost_amount_in_tl, mart_predict)
# Out:
# 428.18266268643464

# %%
mart_predict = pd.DataFrame(mart_predict)
mart_data.total_cost_amount_in_tl,mart_predict
# Out:
# (id
#  06KGX4F3    7000.0
#  06OXNBN0    2350.0
#  08WH8WLP    2400.0
#  08XFCSA4    2600.0
#  0A2OCHU5    2500.0
#               ...
#  Z6M54G3W    1450.0
#  ZE9K9XL5    6750.0
#  ZF0KY8KM    1500.0
#  ZRQPTNI7    6300.0
#  ZY2K6IS4    6300.0
#  Name: total_cost_amount_in_tl, Length: 330, dtype: float64,
#                 0
#  0    6503.038086
#  1    2382.548584
#  2    2382.548584
#  3    2311.410889
#  4    2311.410889
#  ..           ...
#  325  1829.888062
#  326  5139.429688
#  327  1573.593628
#  328  5745.820312
#  329  5783.967773
#
#  [330 rows x 1 columns])

# %%
differances = []
predict_mart = []
for i in range(330):
    differances.append(mart_predict.iloc[i:i+1]- mart_data.total_cost_amount_in_tl.iloc[i])
    predict_mart.append(mart_predict.iloc[i:i+1])
    i += 1
differances
# Out:
# [            0
#  0 -496.961914,
#             0
#  1  32.548584,
#             0
#  2 -17.451416,
#              0
#  3 -288.589111,
#              0
#  4 -188.589111,
#              0
#  5  758.214233,
#              0
#  6  121.169189,
#              0
#  7 -421.154053,
#              0
#  8  182.548584,
#              0
#  9  182.548584,
#               0
#  10 -688.589111,
#              0
#  11 -17.451416,
#                0
#  12 -1369.787598,
#                0
#  13 -2893.416992,
#               0
#  14 -117.451416,
#               0
#  15  421.306763,
#               0
#  16 -288.589111,
#               0
#  17 -1319.05127,
#               0
#  18 -971.616943,
#               0
#  19  182.548584,
#              0
#  20 -99.196289,
#               0
#  21 -496.961914,
#               0
#  22  439.679688,
#               0
#  23 -117.451416,
#                0
#  24 -1601.225952,
#               0
#  25 -288.589111,
#               0
#  26 -349.960449,
#               0
#  27 -188.589111,
#               0
#  28  343.617798,
#                0
#  29  1141.525146,
#               0
#  30 -417.451416,
#               0
#  31  379.888062,
#               0
#  32 -117.451416,
#               0
#  33 -288.589111,
#               0
#  34 -288.589111,
#               0
#  35 -288.589111,
#               0
#  36  132.548584,
#               0
#  37  132.548584,
#               0
#  38  179.888062,
#               0
#  39 -188.589111,
#               0
#  40  189.371582,
#               0
#  41  132.548584,
#                0
#  42 -1750.241211,
#              0
#  43 -46.021973,
#               0
#  44 -188.589111,
#               0
#  45 -288.589111,
#               0
#  46  132.548584,
#               0
#  47 -288.589111,
#              0
#  48  32.548584,
#               0
#  49  379.888062,
#               0
#  50  182.548584,
#               0
#  51  132.548584,
#               0
#  52  132.548584,
#               0
#  53 -766.588379,
#               0
#  54 -188.589111,
#               0
#  55 -1035.26416,
#                0
#  56 -1504.179688,
#               0
#  57 -288.589111,
#               0
#  58 -288.589111,
#               0
#  59  1136.84668,
#               0
#  60 -288.589111,
#               0
#  61  121.169189,
#               0
#  62  121.897949,
#               0
#  63  384.356812,
#                0
#  64 -1665.090332,
#               0
#  65 -288.589111,
#               0
#  66 -121.588379,
#               0
#  67  121.169189,
#               0
#  68 -814.454834,
#               0
#  69 -288.589111,
#                0
#  70 -1504.179688,
#               0
#  71 -496.961914,
#              0
#  72  32.548584,
#               0
#  73 -117.451416,
#               0
#  74  503.326904,
#               0
#  75 -188.589111,
#              0
#  76 -533.93457,
#               0
#  77 -288.589111,
#               0
#  78  152.053711,
#                0
#  79  1023.402832,
#               0
#  80  182.548584,
#              0
#  81  71.336914,
#              0
#  82  32.548584,
#               0
#  83 -288.589111,
#               0
#  84  182.548584,
#                0
#  85 -1567.751953,
#               0
#  86  143.617798,
#               0
#  87 -288.589111,
#               0
#  88  121.169189,
#               0
#  89  479.888062,
#               0
#  90  457.417969,
#              0
#  91  32.548584,
#              0
#  92  44.528687,
#               0
#  93  1903.20752,
#               0
#  94  132.548584,
#               0
#  95  434.356812,
#               0
#  96  132.548584,
#               0
#  97 -288.589111,
#                0
#  98  1108.195312,
#               0
#  99  321.897949,
#                0
#  100  132.548584,
#                0
#  101 -188.589111,
#                0
#  102 -288.589111,
#                0
#  103  379.888062,
#                0
#  104  182.548584,
#               0
#  105  32.548584,
#                0
#  106  392.909546,
#                 0
#  107 -1377.518555,
#                0
#  108  182.548584,
#                0
#  109 -496.673096,
#                 0
#  110  2666.282227,
#                0
#  111 -688.589111,
#                0
#  112  471.046753,
#                0
#  113  820.077393,
#               0
#  114 -1496.7677,
#                 0
#  115 -1227.268066,
#               0
#  116 -46.021973,
#                0
#  117 -288.589111,
#                0
#  118  121.169189,
#                0
#  119 -288.589111,
#                0
#  120 -288.589111,
#                0
#  121  712.856567,
#               0
#  122  82.548584,
#                0
#  123 -188.589111,
#                0
#  124 -288.589111,
#               0
#  125 -509.90918,
#               0
#  126  32.548584,
#                0
#  127  706.984009,
#               0
#  128  32.548584,
#                0
#  129  106.391113,
#                0
#  130 -389.012695,
#                 0
#  131  1108.195312,
#                0
#  132 -288.589111,
#                0
#  133  297.866699,
#               0
#  134  32.548584,
#                0
#  135  343.617798,
#                0
#  136 -117.451416,
#                0
#  137 -288.589111,
#                0
#  138  467.852661,
#                0
#  139  457.417969,
#               0
#  140 -45.268066,
#                0
#  141  762.856567,
#               0
#  142 -46.021973,
#                0
#  143  132.548584,
#                0
#  144 -432.147339,
#                0
#  145 -117.451416,
#                0
#  146 -416.032227,
#                0
#  147  182.548584,
#                0
#  148 -162.603516,
#                0
#  149  132.548584,
#                0
#  150  132.548584,
#               0
#  151 -17.451416,
#                0
#  152 -339.849976,
#                0
#  153 -288.589111,
#                0
#  154  318.965332,
#                0
#  155  778.155029,
#                0
#  156  121.169189,
#                 0
#  157  2966.282227,
#               0
#  158  32.548584,
#                0
#  159  132.548584,
#               0
#  160  32.548584,
#               0
#  161 -209.90918,
#                0
#  162  132.548584,
#               0
#  163 -509.90918,
#                0
#  164  249.233276,
#                0
#  165  379.888062,
#                0
#  166 -421.189575,
#              0
#  167 -86.28418,
#                0
#  168  121.169189,
#               0
#  169  32.548584,
#                0
#  170  182.548584,
#                0
#  171 -688.589111,
#                 0
#  172 -1071.616943,
#                0
#  173  182.548584,
#                0
#  174 -288.589111,
#                 0
#  175 -1051.381348,
#                0
#  176  132.548584,
#                0
#  177 -288.589111,
#                0
#  178  132.548584,
#                0
#  179 -474.407715,
#                0
#  180 -288.589111,
#                0
#  181  121.169189,
#                0
#  182 -356.382202,
#                 0
#  183 -1567.751953,
#               0
#  184  498.82666,
#                0
#  185 -880.066895,
#                0
#  186 -349.960449,
#               0
#  187  32.548584,
#                 0
#  188 -1837.726074,
#                0
#  189 -317.451416,
#                0
#  190 -978.102051,
#                0
#  191  221.169189,
#               0
#  192  21.169189,
#                0
#  193  182.548584,
#                0
#  194  121.897949,
#                0
#  195 -288.589111,
#                0
#  196  132.548584,
#                0
#  197  345.125732,
#                 0
#  198 -1037.726074,
#                0
#  199 -162.603516,
#                0
#  200 -288.589111,
#                0
#  201 -117.451416,
#               0
#  202 -509.90918,
#                0
#  203  182.548584,
#                0
#  204 -288.589111,
#                0
#  205  223.733154,
#               0
#  206  32.548584,
#                0
#  207  182.548584,
#                0
#  208 -496.961914,
#               0
#  209  32.548584,
#               0
#  210 -89.012695,
#                0
#  211 -496.961914,
#                0
#  212 -117.451416,
#                0
#  213  411.741211,
#               0
#  214  32.548584,
#                0
#  215  249.233276,
#                0
#  216 -341.785767,
#                0
#  217 -288.589111,
#                 0
#  218 -1621.992188,
#               0
#  219  371.18457,
#                0
#  220 -288.589111,
#                0
#  221 -258.047729,
#                 0
#  222 -1029.442871,
#               0
#  223  32.548584,
#                0
#  224 -188.589111,
#                0
#  225  166.937744,
#                0
#  226  458.536133,
#               0
#  227 -17.451416,
#                 0
#  228 -1567.751953,
#                0
#  229  182.548584,
#                0
#  230  121.897949,
#                 0
#  231 -2111.394043,
#                0
#  232  182.548584,
#                0
#  233 -688.589111,
#               0
#  234  32.548584,
#                0
#  235  121.169189,
#               0
#  236 -533.93457,
#                0
#  237 -193.651978,
#                 0
#  238 -3891.902832,
#                0
#  239 -117.451416,
#                0
#  240  132.548584,
#                0
#  241  121.169189,
#                0
#  242  121.169189,
#               0
#  243  566.06543,
#                0
#  244 -288.589111,
#                0
#  245 -240.183105,
#                0
#  246  143.617798,
#                 0
#  247 -1037.726074,
#                0
#  248  242.314941,
#                0
#  249  182.548584,
#                0
#  250  132.548584,
#                0
#  251 -288.589111,
#                0
#  252  132.548584,
#                0
#  253  249.233276,
#                0
#  254  139.673828,
#               0
#  255  32.548584,
#                 0
#  256  1414.353516,
#                 0
#  257 -1287.192261,
#                0
#  258 -637.143433,
#                0
#  259 -288.589111,
#                 0
#  260 -2479.436523,
#               0
#  261  32.548584,
#                0
#  262 -614.454834,
#                0
#  263 -496.673096,
#                 0
#  264 -1029.442871,
#                0
#  265 -188.589111,
#                0
#  266 -288.589111,
#               0
#  267 -17.451416,
#               0
#  268 -209.90918,
#                0
#  269  249.233276,
#                0
#  270 -609.384521,
#               0
#  271  32.548584,
#                0
#  272 -417.451416,
#                0
#  273  182.548584,
#                 0
#  274 -1655.993652,
#                0
#  275  182.548584,
#               0
#  276  32.548584,
#                0
#  277 -188.589111,
#               0
#  278 -309.90918,
#                0
#  279  182.548584,
#                0
#  280 -288.589111,
#                 0
#  281 -1567.751953,
#                0
#  282 -117.451416,
#                0
#  283  182.548584,
#                0
#  284  182.548584,
#               0
#  285  32.548584,
#                0
#  286 -288.589111,
#                0
#  287 -496.961914,
#                0
#  288 -188.589111,
#               0
#  289  32.548584,
#                0
#  290 -288.589111,
#                0
#  291 -217.451416,
#                0
#  292 -288.589111,
#                0
#  293 -288.589111,
#                0
#  294 -188.589111,
#                0
#  295 -496.961914,
#               0
#  296  32.548584,
#                0
#  297  182.548584,
#               0
#  298 -509.90918,
#                0
#  299 -878.102051,
#                0
#  300 -496.961914,
#                0
#  301  132.548584,
#                0
#  302  132.548584,
#                0
#  303 -288.589111,
#                0
#  304 -496.961914,
#                0
#  305  182.548584,
#                0
#  306 -191.604248,
#                0
#  307 -117.451416,
#                0
#  308  473.045166,
#               0
#  309  32.548584,
#               0
#  310 -17.451416,
#                0
#  311 -288.589111,
#                0
#  312 -288.589111,
#                0
#  313  673.593628,
#                0
#  314  132.548584,
#                 0
#  315  1108.195312,
#                0
#  316 -117.451416,
#                0
#  317  712.856567,
#                0
#  318 -544.123169,
#               0
#  319  32.548584,
#                0
#  320  182.548584,
#                0
#  321  132.548584,
#                0
#  322 -550.766724,
#                0
#  323  762.596558,
#                0
#  324  411.741211,
#                0
#  325  379.888062,
#                 0
#  326 -1610.570312,
#               0
#  327  73.593628,
#                0
#  328 -554.179688,
#                0
#  329 -516.032227]

# %%
in_one_mse= []
for i in range(330):
    in_one_mse.append(differances[i]**2 < metrics.mean_squared_error(mart_data.total_cost_amount_in_tl, mart_predict))
    i = i+ 1

# %%
between_one_three_mse = []
for i in range(330):
    between_one_three_mse.append((differances[i]**2 > (metrics.mean_squared_error(mart_data.total_cost_amount_in_tl, mart_predict))) & (differances[i]**2 < 3*metrics.mean_squared_error(mart_data.total_cost_amount_in_tl,mart_predict)))
    i = i+ 1

# %%
more_than_three_mse = []
for i in range(330):
    more_than_three_mse.append(differances[i]**2 > 3*(metrics.mean_squared_error(mart_data.total_cost_amount_in_tl, mart_predict)))
    i = i+ 1

# %%
final = pd.DataFrame()
final['total_cost'] = mart_data.total_cost_amount_in_tl
final['mart_predict'] = predict_mart
final['differances'] = differances
final['in_one_mse'] = in_one_mse
final['between_one_three_mse'] = between_one_three_mse
final['more_than_three_mse'] = more_than_three_mse
final['invoice_company_title'] = orj_mart_data.invoice_company_title
final['routes'] = orj_mart_data.routes
final['totalkgds'] = orj_mart_data.totalkgds
final['vehicle_body_type'] = orj_mart_data.vehicle_body_type
final['vehicle_package_type'] = orj_mart_data.vehicle_package_type
final['km'] = orj_mart_data.km
final['kursunsuz_v_max'] = orj_mart_data.kursunsuz_v_max
final
# Out:
#           total_cost                       mart_predict  \
# id
# 06KGX4F3      7000.0                   0
# 0  6503.038086
# 06OXNBN0      2350.0                   0
# 1  2382.548584
# 08WH8WLP      2400.0                   0
# 2  2382.548584
# 08XFCSA4      2600.0                   0
# 3  2311.410889
# 0A2OCHU5      2500.0                   0
# 4  2311.410889
# ...              ...                                ...
# Z6M54G3W      1450.0                 0
# 325  1829.888062
# ZE9K9XL5      6750.0                 0
# 326  5139.429688
# ZF0KY8KM      1500.0                 0
# 327  1573.593628
# ZRQPTNI7      6300.0                 0
# 328  5745.820312
# ZY2K6IS4      6300.0                 0
# 329  5783.967773
#
#                                 differances             in_one_mse  \
# id
# 06KGX4F3                    0
# 0 -496.961914              0
# 0  True
# 06OXNBN0                     0
# 1  32.548584              0
# 1  True
# 08WH8WLP                     0
# 2 -17.451416              0
# 2  True
# 08XFCSA4                    0
# 3 -288.589111              0
# 3  True
# 0A2OCHU5                    0
# 4 -188.589111              0
# 4  True
# ...                                     ...                    ...
# Z6M54G3W                  0
# 325  379.888062            0
# 325  True
# ZE9K9XL5                 0
# 326 -1610.570312           0
# 326  False
# ZF0KY8KM                   0
# 327  73.593628            0
# 327  True
# ZRQPTNI7                  0
# 328 -554.179688            0
# 328  True
# ZY2K6IS4                  0
# 329 -516.032227            0
# 329  True
#
#           between_one_three_mse    more_than_three_mse  \
# id
# 06KGX4F3             0
# 0  False             0
# 0  False
# 06OXNBN0             0
# 1  False             0
# 1  False
# 08WH8WLP             0
# 2  False             0
# 2  False
# 08XFCSA4             0
# 3  False             0
# 3  False
# 0A2OCHU5             0
# 4  False             0
# 4  False
# ...                         ...                    ...
# Z6M54G3W           0
# 325  False           0
# 325  False
# ZE9K9XL5           0
# 326  False            0
# 326  True
# ZF0KY8KM           0
# 327  False           0
# 327  False
# ZRQPTNI7           0
# 328  False           0
# 328  False
# ZY2K6IS4           0
# 329  False           0
# 329  False
#
#                           invoice_company_title            routes  totalkgds  \
# id
# 06KGX4F3            Barilla Gıda Anonim Şirketi       Burdur_Bolu    25000.0
# 06OXNBN0  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.     Bursa_Kocaeli    25000.0
# 08WH8WLP  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.     Bursa_Kocaeli    25000.0
# 08XFCSA4  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.     Bursa_Kocaeli    25000.0
# 0A2OCHU5  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.     Bursa_Kocaeli    25000.0
# ...                                         ...               ...        ...
# Z6M54G3W       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ   Kocaeli_Kocaeli    25152.0
# ZE9K9XL5       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ     Kocaeli_İzmir    25000.0
# ZF0KY8KM       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ  Kocaeli_İstanbul    13740.0
# ZRQPTNI7                  TRENDYOL LOJISTIK A.Ş    İstanbul_İzmir    10000.0
# ZY2K6IS4            Barilla Gıda Anonim Şirketi       Burdur_Bolu    25000.0
#
#          vehicle_body_type vehicle_package_type     km  kursunsuz_v_max
# id
# 06KGX4F3         TAUTLINER               PALLET  566.4            20.38
# 06OXNBN0           FLATBED                OTHER  132.4            17.98
# 08WH8WLP           FLATBED                OTHER  132.4            18.69
# 08XFCSA4           FLATBED                OTHER  132.4            20.38
# 0A2OCHU5           FLATBED                OTHER  132.4            20.38
# ...                    ...                  ...    ...              ...
# Z6M54G3W         TAUTLINER               PALLET    1.0            20.38
# ZE9K9XL5         TAUTLINER               PALLET  461.8            19.27
# ZF0KY8KM         TAUTLINER               PALLET   94.1            17.42
# ZRQPTNI7         TAUTLINER               PALLET  479.0            20.38
# ZY2K6IS4         TAUTLINER               PALLET  566.4            17.98
#
# [330 rows x 13 columns]

# %%
final['more_than_three_mse'] = final['more_than_three_mse'].astype(str).str[-5:]
final['in_one_mse'] = final['in_one_mse'].astype(str).str[-5:]
final['between_one_three_mse'] = final['between_one_three_mse'].astype(str).str[-5:]
final
# Out:
#           total_cost                       mart_predict  \
# id
# 06KGX4F3      7000.0                   0
# 0  6503.038086
# 06OXNBN0      2350.0                   0
# 1  2382.548584
# 08WH8WLP      2400.0                   0
# 2  2382.548584
# 08XFCSA4      2600.0                   0
# 3  2311.410889
# 0A2OCHU5      2500.0                   0
# 4  2311.410889
# ...              ...                                ...
# Z6M54G3W      1450.0                 0
# 325  1829.888062
# ZE9K9XL5      6750.0                 0
# 326  5139.429688
# ZF0KY8KM      1500.0                 0
# 327  1573.593628
# ZRQPTNI7      6300.0                 0
# 328  5745.820312
# ZY2K6IS4      6300.0                 0
# 329  5783.967773
#
#                                 differances in_one_mse between_one_three_mse  \
# id
# 06KGX4F3                    0
# 0 -496.961914       True                 False
# 06OXNBN0                     0
# 1  32.548584       True                 False
# 08WH8WLP                     0
# 2 -17.451416       True                 False
# 08XFCSA4                    0
# 3 -288.589111       True                 False
# 0A2OCHU5                    0
# 4 -188.589111       True                 False
# ...                                     ...        ...                   ...
# Z6M54G3W                  0
# 325  379.888062       True                 False
# ZE9K9XL5                 0
# 326 -1610.570312      False                 False
# ZF0KY8KM                   0
# 327  73.593628       True                 False
# ZRQPTNI7                  0
# 328 -554.179688       True                 False
# ZY2K6IS4                  0
# 329 -516.032227       True                 False
#
#          more_than_three_mse                  invoice_company_title  \
# id
# 06KGX4F3               False            Barilla Gıda Anonim Şirketi
# 06OXNBN0               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# 08WH8WLP               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# 08XFCSA4               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# 0A2OCHU5               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# ...                      ...                                    ...
# Z6M54G3W               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# ZE9K9XL5                True       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# ZF0KY8KM               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# ZRQPTNI7               False                  TRENDYOL LOJISTIK A.Ş
# ZY2K6IS4               False            Barilla Gıda Anonim Şirketi
#
#                     routes  totalkgds vehicle_body_type vehicle_package_type  \
# id
# 06KGX4F3       Burdur_Bolu    25000.0         TAUTLINER               PALLET
# 06OXNBN0     Bursa_Kocaeli    25000.0           FLATBED                OTHER
# 08WH8WLP     Bursa_Kocaeli    25000.0           FLATBED                OTHER
# 08XFCSA4     Bursa_Kocaeli    25000.0           FLATBED                OTHER
# 0A2OCHU5     Bursa_Kocaeli    25000.0           FLATBED                OTHER
# ...                    ...        ...               ...                  ...
# Z6M54G3W   Kocaeli_Kocaeli    25152.0         TAUTLINER               PALLET
# ZE9K9XL5     Kocaeli_İzmir    25000.0         TAUTLINER               PALLET
# ZF0KY8KM  Kocaeli_İstanbul    13740.0         TAUTLINER               PALLET
# ZRQPTNI7    İstanbul_İzmir    10000.0         TAUTLINER               PALLET
# ZY2K6IS4       Burdur_Bolu    25000.0         TAUTLINER               PALLET
#
#              km  kursunsuz_v_max
# id
# 06KGX4F3  566.4            20.38
# 06OXNBN0  132.4            17.98
# 08WH8WLP  132.4            18.69
# 08XFCSA4  132.4            20.38
# 0A2OCHU5  132.4            20.38
# ...         ...              ...
# Z6M54G3W    1.0            20.38
# ZE9K9XL5  461.8            19.27
# ZF0KY8KM   94.1            17.42
# ZRQPTNI7  479.0            20.38
# ZY2K6IS4  566.4            17.98
#
# [330 rows x 13 columns]

# %%
final_more_than_three_mse = final[final['more_than_three_mse'] == ' True']
final_more_than_three_mse.sort_values(by = 'total_cost')
# Out:
#           total_cost                       mart_predict  \
# id
# 9D3DYGNU       800.0                   0
# 93  2703.20752
# 17TJOI8M      3000.0                   0
# 17  1680.94873
# SMMUMYXL      3000.0                 0
# 257  1712.807739
# DCID03P7      3000.0                   0
# 114  1503.2323
# 1ZHPOX8J      3400.0                  0
# 24  1798.774048
# 715EAVVN      3400.0                  0
# 64  1734.909668
# 0UGJJH6O      3900.0                  0
# 12  2530.212402
# SNP5572D      3950.0                 0
# 260  1470.563477
# SIJ1JVPS      4100.0                 0
# 256  5514.353516
# LYQYOTOH      6000.0                 0
# 188  4162.273926
# IGQK5ZD1      6500.0                 0
# 157  9466.282227
# DF48EDU7      6500.0                 0
# 115  5272.731934
# C85FJZLC      6700.0                 0
# 107  5322.481445
# UJFI7DKW      6700.0                 0
# 281  5132.248047
# 8AO17CTH      6700.0                  0
# 85  5132.248047
# L16AK66N      6700.0                 0
# 183  5132.248047
# QCBJECA4      6700.0                 0
# 228  5132.248047
# ZE9K9XL5      6750.0                 0
# 326  5139.429688
# TUF4JH6O      6800.0                 0
# 274  5144.006348
# CWZOG53X      6800.0                 0
# 110  9466.282227
# P9BDP9FZ      7000.0                 0
# 218  5378.007812
# 74W10NRZ      7250.0                  0
# 70  5745.820312
# 6MHOIINL      7250.0                  0
# 56  5745.820312
# QHY3ONUS      7300.0                 0
# 231  5188.605957
# 4FSPAFMY      7500.0                  0
# 42  5749.758789
# 0V2L088U      8000.0                  0
# 13  5106.583008
# R33Q40YW      9000.0                 0
# 238  5108.097168
#
#                                 differances in_one_mse between_one_three_mse  \
# id
# 9D3DYGNU                   0
# 93  1903.20752      False                 False
# 17TJOI8M                   0
# 17 -1319.05127      False                 False
# SMMUMYXL                 0
# 257 -1287.192261      False                 False
# DCID03P7                   0
# 114 -1496.7677      False                 False
# 1ZHPOX8J                  0
# 24 -1601.225952      False                 False
# 715EAVVN                  0
# 64 -1665.090332      False                 False
# 0UGJJH6O                  0
# 12 -1369.787598      False                 False
# SNP5572D                 0
# 260 -2479.436523      False                 False
# SIJ1JVPS                 0
# 256  1414.353516      False                 False
# LYQYOTOH                 0
# 188 -1837.726074      False                 False
# IGQK5ZD1                 0
# 157  2966.282227      False                 False
# DF48EDU7                 0
# 115 -1227.268066      False                 False
# C85FJZLC                 0
# 107 -1377.518555      False                 False
# UJFI7DKW                 0
# 281 -1567.751953      False                 False
# 8AO17CTH                  0
# 85 -1567.751953      False                 False
# L16AK66N                 0
# 183 -1567.751953      False                 False
# QCBJECA4                 0
# 228 -1567.751953      False                 False
# ZE9K9XL5                 0
# 326 -1610.570312      False                 False
# TUF4JH6O                 0
# 274 -1655.993652      False                 False
# CWZOG53X                 0
# 110  2666.282227      False                 False
# P9BDP9FZ                 0
# 218 -1621.992188      False                 False
# 74W10NRZ                  0
# 70 -1504.179688      False                 False
# 6MHOIINL                  0
# 56 -1504.179688      False                 False
# QHY3ONUS                 0
# 231 -2111.394043      False                 False
# 4FSPAFMY                  0
# 42 -1750.241211      False                 False
# 0V2L088U                  0
# 13 -2893.416992      False                 False
# R33Q40YW                 0
# 238 -3891.902832      False                 False
#
#          more_than_three_mse  \
# id
# 9D3DYGNU                True
# 17TJOI8M                True
# SMMUMYXL                True
# DCID03P7                True
# 1ZHPOX8J                True
# 715EAVVN                True
# 0UGJJH6O                True
# SNP5572D                True
# SIJ1JVPS                True
# LYQYOTOH                True
# IGQK5ZD1                True
# DF48EDU7                True
# C85FJZLC                True
# UJFI7DKW                True
# 8AO17CTH                True
# L16AK66N                True
# QCBJECA4                True
# ZE9K9XL5                True
# TUF4JH6O                True
# CWZOG53X                True
# P9BDP9FZ                True
# 74W10NRZ                True
# 6MHOIINL                True
# QHY3ONUS                True
# 4FSPAFMY                True
# 0V2L088U                True
# R33Q40YW                True
#
#                                       invoice_company_title  \
# id
# 9D3DYGNU                           POLİN KİMYA SAN.TİC.A.Ş.
# 17TJOI8M              TAMAŞ MAKİNA VE KİMYA SAN TİC LTD ŞTİ
# SMMUMYXL                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# DCID03P7              BEYDA GIDA ÜRÜNLERİ SAN. VE TİC. A.Ş.
# 1ZHPOX8J                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 715EAVVN                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 0UGJJH6O              BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# SNP5572D  Koroplast Temizlik Ambalaj Ürün.San.ve Dış Tic...
# SIJ1JVPS                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# LYQYOTOH              BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# IGQK5ZD1              BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# DF48EDU7                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# C85FJZLC                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# UJFI7DKW                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 8AO17CTH                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# L16AK66N                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# QCBJECA4                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# ZE9K9XL5                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# TUF4JH6O                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# CWZOG53X              BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# P9BDP9FZ                   ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 74W10NRZ                              TRENDYOL LOJISTIK A.Ş
# 6MHOIINL                              TRENDYOL LOJISTIK A.Ş
# QHY3ONUS   PETIUM GIDA EVCIL HAYVAN URUNLERI SAN. TIC. LTD.
# 4FSPAFMY                              TRENDYOL LOJISTIK A.Ş
# 0V2L088U                            SÜTAŞ SÜT ÜRÜNLERİ A.Ş.
# R33Q40YW      KNAUF İNŞAAT VE YAPI ELEMANLARI SAN. TİC. AŞ.
#
#                      routes  totalkgds vehicle_body_type vehicle_package_type  \
# id
# 9D3DYGNU   Kocaeli_İstanbul    26000.0         TAUTLINER                  NaN
# 17TJOI8M   İstanbul_Kocaeli     4000.0         TAUTLINER                  NaN
# SMMUMYXL   Kocaeli_İstanbul     5685.0         TAUTLINER               PALLET
# DCID03P7  İstanbul_İstanbul    17500.0         TAUTLINER                  NaN
# 1ZHPOX8J   Kocaeli_İstanbul    21228.0         TAUTLINER               PALLET
# 715EAVVN   Kocaeli_İstanbul    15247.0         TAUTLINER               PALLET
# 0UGJJH6O      Bursa_Kocaeli    20000.0           FLATBED                OTHER
# SNP5572D  İstanbul_İstanbul    20000.0         TAUTLINER               PALLET
# SIJ1JVPS      Kocaeli_İzmir    10961.0         TAUTLINER               PALLET
# LYQYOTOH     Bursa_İstanbul    25000.0           FLATBED                OTHER
# IGQK5ZD1      Bursa_Kayseri    25000.0           FLATBED                OTHER
# DF48EDU7      Kocaeli_İzmir    24764.0         TAUTLINER               PALLET
# C85FJZLC      Kocaeli_İzmir    21492.0         TAUTLINER               PALLET
# UJFI7DKW      Kocaeli_İzmir    25096.0         TAUTLINER               PALLET
# 8AO17CTH      Kocaeli_İzmir    25096.0         TAUTLINER               PALLET
# L16AK66N      Kocaeli_İzmir    25212.0         TAUTLINER               PALLET
# QCBJECA4      Kocaeli_İzmir    25096.0         TAUTLINER               PALLET
# ZE9K9XL5      Kocaeli_İzmir    25000.0         TAUTLINER               PALLET
# TUF4JH6O      Kocaeli_İzmir    15312.0         TAUTLINER               PALLET
# CWZOG53X      Bursa_Kayseri    25000.0           FLATBED                OTHER
# P9BDP9FZ      Kocaeli_İzmir    23880.0         TAUTLINER               PALLET
# 74W10NRZ     İstanbul_İzmir    10000.0         TAUTLINER               PALLET
# 6MHOIINL     İstanbul_İzmir    10000.0         TAUTLINER               PALLET
# QHY3ONUS    İstanbul_Ankara    20000.0         TAUTLINER                  NaN
# 4FSPAFMY     İstanbul_İzmir    10000.0         TAUTLINER               PALLET
# 0V2L088U     İstanbul_İzmir     7000.0         TAUTLINER                  NaN
# R33Q40YW      Kocaeli_İzmir    26000.0         TAUTLINER                  NaN
#
#              km  kursunsuz_v_max
# id
# 9D3DYGNU   94.1            20.35
# 17TJOI8M  103.9            17.98
# SMMUMYXL   94.1            17.42
# DCID03P7    1.0            17.42
# 1ZHPOX8J   94.1            20.35
# 715EAVVN   94.1            20.38
# 0UGJJH6O  132.4            19.27
# SNP5572D    1.0            20.38
# SIJ1JVPS  461.8            16.53
# LYQYOTOH  153.3            20.38
# IGQK5ZD1  665.9            20.38
# DF48EDU7  461.8            17.98
# C85FJZLC  461.8            20.38
# UJFI7DKW  461.8            20.35
# 8AO17CTH  461.8            20.38
# L16AK66N  461.8            20.35
# QCBJECA4  461.8            20.38
# ZE9K9XL5  461.8            19.27
# TUF4JH6O  461.8            20.35
# CWZOG53X  665.9            20.35
# P9BDP9FZ  461.8            20.38
# 74W10NRZ  479.0            20.38
# 6MHOIINL  479.0            20.38
# QHY3ONUS  443.9            20.35
# 4FSPAFMY  479.0            20.35
# 0V2L088U  479.0            20.35
# R33Q40YW  461.8            20.38

# %%
final_more_than_three_mse.shape
# Out:
# (27, 13)

# %%
final_between_one_three_mse = final[final['between_one_three_mse'] == ' True']
final_between_one_three_mse
# Out:
#           total_cost                       mart_predict  \
# id
# 0AU9UY0P       900.0                   0
# 5  1658.214233
# 0TI75KYN      3000.0                  0
# 10  2311.410889
# 1CCA2KVH      3400.0                  0
# 18  2428.383057
# 28B4ENRX      1350.0                  0
# 29  2491.525146
# 66SZRSCN      5000.0                  0
# 53  4233.411621
# 6ATYAZK8      3400.0                   0
# 55  2364.73584
# 6TP7ICG3      1350.0                   0
# 59  2486.84668
# 73W7QC1G      3200.0                  0
# 68  2385.545166
# 7WL1KD5C      4600.0                  0
# 79  5623.402832
# AECFC51A      4500.0                  0
# 98  5608.195312
# CXGE5RPT      3000.0                 0
# 111  2311.410889
# DATHVLRO       950.0                 0
# 113  1770.077393
# DRQVAEBP       950.0                 0
# 121  1662.856567
# E56N2774       900.0                 0
# 127  1606.984009
# EEXS0ZKZ      4500.0                 0
# 131  5608.195312
# GJ0O2RJ3       900.0                 0
# 141  1662.856567
# I3S5B53S       800.0                 0
# 155  1578.155029
# JH39JADT      3000.0                 0
# 171  2311.410889
# JPL7XMGN      3500.0                 0
# 172  2428.383057
# JXXPB60B      6500.0                 0
# 175  5448.618652
# LFEYM08C      3300.0                 0
# 185  2419.933105
# M2ACAKOO      3300.0                 0
# 190  2321.897949
# N50RE18L      5200.0                 0
# 198  4162.273926
# PHWU9XJK      6000.0                 0
# 222  4970.557129
# QR0OB2MN      3000.0                 0
# 233  2311.410889
# RPASTGS6      5200.0                 0
# 247  4162.273926
# T2DBH9LP      6000.0                 0
# 264  4970.557129
# WMGQGZDX      3200.0                 0
# 299  2321.897949
# Y46RUJWO       900.0                 0
# 313  1573.593628
# Y8I24QA4      4500.0                 0
# 315  5608.195312
# YJWR9B4Q       950.0                 0
# 317  1662.856567
# Z55W0Q4G       950.0                 0
# 323  1712.596558
#
#                                 differances in_one_mse between_one_three_mse  \
# id
# 0AU9UY0P                    0
# 5  758.214233      False                  True
# 0TI75KYN                   0
# 10 -688.589111      False                  True
# 1CCA2KVH                   0
# 18 -971.616943      False                  True
# 28B4ENRX                  0
# 29  1141.525146      False                  True
# 66SZRSCN                   0
# 53 -766.588379      False                  True
# 6ATYAZK8                   0
# 55 -1035.26416      False                  True
# 6TP7ICG3                   0
# 59  1136.84668      False                  True
# 73W7QC1G                   0
# 68 -814.454834      False                  True
# 7WL1KD5C                  0
# 79  1023.402832      False                  True
# AECFC51A                  0
# 98  1108.195312      False                  True
# CXGE5RPT                  0
# 111 -688.589111      False                  True
# DATHVLRO                  0
# 113  820.077393      False                  True
# DRQVAEBP                  0
# 121  712.856567      False                  True
# E56N2774                  0
# 127  706.984009      False                  True
# EEXS0ZKZ                 0
# 131  1108.195312      False                  True
# GJ0O2RJ3                  0
# 141  762.856567      False                  True
# I3S5B53S                  0
# 155  778.155029      False                  True
# JH39JADT                  0
# 171 -688.589111      False                  True
# JPL7XMGN                 0
# 172 -1071.616943      False                  True
# JXXPB60B                 0
# 175 -1051.381348      False                  True
# LFEYM08C                  0
# 185 -880.066895      False                  True
# M2ACAKOO                  0
# 190 -978.102051      False                  True
# N50RE18L                 0
# 198 -1037.726074      False                  True
# PHWU9XJK                 0
# 222 -1029.442871      False                  True
# QR0OB2MN                  0
# 233 -688.589111      False                  True
# RPASTGS6                 0
# 247 -1037.726074      False                  True
# T2DBH9LP                 0
# 264 -1029.442871      False                  True
# WMGQGZDX                  0
# 299 -878.102051      False                  True
# Y46RUJWO                  0
# 313  673.593628      False                  True
# Y8I24QA4                 0
# 315  1108.195312      False                  True
# YJWR9B4Q                  0
# 317  712.856567      False                  True
# Z55W0Q4G                  0
# 323  762.596558      False                  True
#
#          more_than_three_mse                  invoice_company_title  \
# id
# 0AU9UY0P               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 0TI75KYN               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# 1CCA2KVH               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 28B4ENRX               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 66SZRSCN               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# 6ATYAZK8               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 6TP7ICG3               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 73W7QC1G               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# 7WL1KD5C               False                  TRENDYOL LOJISTIK A.Ş
# AECFC51A               False                  TRENDYOL LOJISTIK A.Ş
# CXGE5RPT               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# DATHVLRO               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# DRQVAEBP               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# E56N2774               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# EEXS0ZKZ               False                  TRENDYOL LOJISTIK A.Ş
# GJ0O2RJ3               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# I3S5B53S               False    Adco Petrol Katkıları San. Tic A.Ş.
# JH39JADT               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# JPL7XMGN               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# JXXPB60B               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# LFEYM08C               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# M2ACAKOO               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# N50RE18L               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# PHWU9XJK               False            Barilla Gıda Anonim Şirketi
# QR0OB2MN               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# RPASTGS6               False  BORUSAN MANNESMANN BORU SAN. TİC. AŞ.
# T2DBH9LP               False            Barilla Gıda Anonim Şirketi
# WMGQGZDX               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# Y46RUJWO               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# Y8I24QA4               False                  TRENDYOL LOJISTIK A.Ş
# YJWR9B4Q               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
# Z55W0Q4G               False       ELFA LOJİSTİK HİZ.VE TİC.LTD.ŞTİ
#
#                     routes  totalkgds vehicle_body_type vehicle_package_type  \
# id
# 0AU9UY0P  Kocaeli_İstanbul    12000.0         TAUTLINER               PALLET
# 0TI75KYN     Bursa_Kocaeli    25000.0           FLATBED                OTHER
# 1CCA2KVH  Kocaeli_İstanbul    25084.0         TAUTLINER               PALLET
# 28B4ENRX   Kocaeli_Kocaeli    22000.0         TAUTLINER               PALLET
# 66SZRSCN    Bursa_İstanbul    25000.0           FLATBED                OTHER
# 6ATYAZK8  Kocaeli_İstanbul    23584.0         TAUTLINER               PALLET
# 6TP7ICG3   Kocaeli_Kocaeli    21636.0         TAUTLINER               PALLET
# 73W7QC1G  Kocaeli_İstanbul    25000.0         TAUTLINER               PALLET
# 7WL1KD5C   İstanbul_Ankara    10000.0         TAUTLINER               PALLET
# AECFC51A   İstanbul_Ankara    10000.0         TAUTLINER               PALLET
# CXGE5RPT     Bursa_Kocaeli    25000.0           FLATBED                OTHER
# DATHVLRO  Kocaeli_İstanbul    14348.0         TAUTLINER               PALLET
# DRQVAEBP  Kocaeli_İstanbul    10744.0         TAUTLINER               PALLET
# E56N2774   Kocaeli_Kocaeli    10143.0         TAUTLINER               PALLET
# EEXS0ZKZ   İstanbul_Ankara    10000.0         TAUTLINER               PALLET
# GJ0O2RJ3  Kocaeli_İstanbul    10744.0         TAUTLINER               PALLET
# I3S5B53S   Kocaeli_Kocaeli    10000.0         TAUTLINER                  NaN
# JH39JADT     Bursa_Kocaeli    25000.0           FLATBED                OTHER
# JPL7XMGN  Kocaeli_İstanbul    25212.0         TAUTLINER               PALLET
# JXXPB60B     Kocaeli_İzmir    21228.0         TAUTLINER               PALLET
# LFEYM08C  Kocaeli_İstanbul    25096.0         TAUTLINER               PALLET
# M2ACAKOO  Kocaeli_İstanbul    24000.0         TAUTLINER               PALLET
# N50RE18L    Bursa_İstanbul    25000.0           FLATBED                OTHER
# PHWU9XJK       Burdur_Bolu    25000.0           FLATBED               PALLET
# QR0OB2MN     Bursa_Kocaeli    25000.0           FLATBED                OTHER
# RPASTGS6    Bursa_İstanbul    25000.0           FLATBED                OTHER
# T2DBH9LP       Burdur_Bolu    25000.0           FLATBED               PALLET
# WMGQGZDX  Kocaeli_İstanbul    24000.0         TAUTLINER               PALLET
# Y46RUJWO  Kocaeli_İstanbul    14000.0         TAUTLINER               PALLET
# Y8I24QA4   İstanbul_Ankara    10000.0         TAUTLINER               PALLET
# YJWR9B4Q  Kocaeli_İstanbul    10744.0         TAUTLINER               PALLET
# Z55W0Q4G  Kocaeli_İstanbul    12852.0         TAUTLINER               PALLET
#
#              km  kursunsuz_v_max
# id
# 0AU9UY0P   94.1            17.42
# 0TI75KYN  132.4            20.38
# 1CCA2KVH   94.1            20.35
# 28B4ENRX    1.0            17.42
# 66SZRSCN  153.3            16.53
# 6ATYAZK8   94.1            20.35
# 6TP7ICG3    1.0            17.98
# 73W7QC1G   94.1            18.69
# 7WL1KD5C  443.9            16.53
# AECFC51A  443.9            20.38
# CXGE5RPT  132.4            20.38
# DATHVLRO   94.1            20.38
# DRQVAEBP   94.1            20.38
# E56N2774    1.0            20.35
# EEXS0ZKZ  443.9            20.38
# GJ0O2RJ3   94.1            20.38
# I3S5B53S    1.0            16.53
# JH39JADT  132.4            20.38
# JPL7XMGN   94.1            20.35
# JXXPB60B  461.8            17.98
# LFEYM08C   94.1            20.38
# M2ACAKOO   94.1            19.27
# N50RE18L  153.3            18.69
# PHWU9XJK  566.4            16.53
# QR0OB2MN  132.4            20.38
# RPASTGS6  153.3            17.98
# T2DBH9LP  566.4            16.53
# WMGQGZDX   94.1            19.27
# Y46RUJWO   94.1            17.42
# Y8I24QA4  443.9            20.38
# YJWR9B4Q   94.1            20.38
# Z55W0Q4G   94.1            20.38

# %%
final_between_one_three_mse.shape
# Out:
# (32, 6)

# %%
final_in_one_mse= final[final['in_one_mse'] == ' True']
final_in_one_mse
# Out:
#           total_cost                         mart_predict  \
# id
# 06KGX4F3      7000.0                     0
# 0  6503.038086
# 06OXNBN0      2350.0                     0
# 1  2382.548584
# 08WH8WLP      2400.0                     0
# 2  2382.548584
# 08XFCSA4      2600.0                     0
# 3  2311.410889
# 0A2OCHU5      2500.0                     0
# 4  2311.410889
# ...              ...                                  ...
# Z5SAU3M4     13850.0                  0
# 324  14261.741211
# Z6M54G3W      1450.0                   0
# 325  1829.888062
# ZF0KY8KM      1500.0                   0
# 327  1573.593628
# ZRQPTNI7      6300.0                   0
# 328  5745.820312
# ZY2K6IS4      6300.0                   0
# 329  5783.967773
#
#                               differances in_one_mse between_one_three_mse  \
# id
# 06KGX4F3                  0
# 0 -496.961914       True                 False
# 06OXNBN0                   0
# 1  32.548584       True                 False
# 08WH8WLP                   0
# 2 -17.451416       True                 False
# 08XFCSA4                  0
# 3 -288.589111       True                 False
# 0A2OCHU5                  0
# 4 -188.589111       True                 False
# ...                                   ...        ...                   ...
# Z5SAU3M4                0
# 324  411.741211       True                 False
# Z6M54G3W                0
# 325  379.888062       True                 False
# ZF0KY8KM                 0
# 327  73.593628       True                 False
# ZRQPTNI7                0
# 328 -554.179688       True                 False
# ZY2K6IS4                0
# 329 -516.032227       True                 False
#
#          more_than_three_mse
# id
# 06KGX4F3               False
# 06OXNBN0               False
# 08WH8WLP               False
# 08XFCSA4               False
# 0A2OCHU5               False
# ...                      ...
# Z5SAU3M4               False
# Z6M54G3W               False
# ZF0KY8KM               False
# ZRQPTNI7               False
# ZY2K6IS4               False
#
# [271 rows x 6 columns]

# %%
final_in_one_mse.shape
# Out:
# (271, 6)

# %%
metrics.mean_squared_error(mart_data.total_cost_amount_in_tl, mart_predict)**(1/2)
# Out:
# 669.799164200482

# %%
three_mse_shipments = []
for i in final_more_than_three_mse.index:
    three_mse_shipments.append(orj_mart_data.loc[i])
three_mse_shipments = pd.DataFrame(three_mse_shipments)
three_mse_shipments = pd.concat([three_mse_shipments['latest_status'],three_mse_shipments['totalkgds'],three_mse_shipments['pickup_city'],three_mse_shipments['dropoff_city'] ,three_mse_shipments['pickup_address_type'], three_mse_shipments['dropoff_address_type'],
                  three_mse_shipments['category'], three_mse_shipments['price_type'], 
                  three_mse_shipments['shipment_type'], three_mse_shipments['vehicle_type'],three_mse_shipments['vehicle_body_type'],
                  three_mse_shipments['vehicle_package_type'], three_mse_shipments['vehicle_way_of_loading'],
                  three_mse_shipments['vehicle_tonnage_per_vehicle'],three_mse_shipments['payment_option'],
                  three_mse_shipments['invoice_type'], three_mse_shipments['tenant_signup_flow'], 
                  three_mse_shipments['total_cost_amount_in_tl'], three_mse_shipments['usd_tl'],
                  three_mse_shipments['price_base_amount_in_tl']
                 ,three_mse_shipments['routes'],three_mse_shipments['km'],three_mse_shipments['kursunsuz_v_max'],three_mse_shipments['pro_dizel']], axis = 1)
three_mse_shipments
three_mse_shipments = three_mse_shipments.drop(columns = 'shipment_type')
three_mse_shipments = three_mse_shipments.drop(columns = 'latest_status')
three_mse_shipments = three_mse_shipments.drop(columns = 'price_base_amount_in_tl')
three_mse_shipments = three_mse_shipments.drop(columns = 'price_type')
three_mse_shipments = three_mse_shipments.drop(columns = 'payment_option')
three_mse_shipments = three_mse_shipments.drop(columns = 'invoice_type')
three_mse_shipments = three_mse_shipments.drop(columns = 'tenant_signup_flow')
three_mse_shipments = three_mse_shipments.drop(columns = drops)

pd.concat([three_mse_shipments,final_more_than_three_mse.mart_predict,final_more_than_three_mse.differances],axis= 1)

# %%
pd.concat([three_mse_shipments,final_more_than_three_mse.mart_predict,final_more_than_three_mse.differances],axis= 1).shape

# %%
two_mse_shipments = []
for i in final_between_one_three_mse.index:
    two_mse_shipments.append(orj_mart_data.loc[i])
two_mse_shipments = pd.DataFrame(two_mse_shipments)
two_mse_shipments = pd.concat([two_mse_shipments['latest_status'],two_mse_shipments['totalkgds'],two_mse_shipments['pickup_city'],two_mse_shipments['dropoff_city'] ,two_mse_shipments['pickup_address_type'], two_mse_shipments['dropoff_address_type'],
                  two_mse_shipments['category'], two_mse_shipments['price_type'], 
                  two_mse_shipments['shipment_type'], two_mse_shipments['vehicle_type'],two_mse_shipments['vehicle_body_type'],
                  two_mse_shipments['vehicle_package_type'], two_mse_shipments['vehicle_way_of_loading'],
                  two_mse_shipments['vehicle_tonnage_per_vehicle'],two_mse_shipments['payment_option'],
                  two_mse_shipments['invoice_type'], two_mse_shipments['tenant_signup_flow'], 
                  two_mse_shipments['total_trip_cost_amount_in_tl'], two_mse_shipments['usd_tl'],
                  two_mse_shipments['price_base_amount_in_tl']
                 ,two_mse_shipments['routes'],two_mse_shipments['km'],two_mse_shipments['kursunsuz_v_max'],two_mse_shipments['pro_dizel']], axis = 1)
two_mse_shipments
two_mse_shipments = two_mse_shipments.drop(columns = 'shipment_type')
two_mse_shipments = two_mse_shipments.drop(columns = 'latest_status')
two_mse_shipments = two_mse_shipments.drop(columns = 'price_base_amount_in_tl')
two_mse_shipments = two_mse_shipments.drop(columns = 'price_type')
two_mse_shipments = two_mse_shipments.drop(columns = 'payment_option')
two_mse_shipments = two_mse_shipments.drop(columns = 'invoice_type')
two_mse_shipments = two_mse_shipments.drop(columns = 'tenant_signup_flow')
two_mse_shipments = two_mse_shipments.drop(columns = drops)

pd.concat([two_mse_shipments,final_between_one_three_mse.mart_predict,final_between_one_three_mse.differances],axis= 1)

# %%
pd.concat([two_mse_shipments,final_between_one_three_mse.mart_predict,final_between_one_three_mse.differances],axis= 1).shape

# %%
reason_data = orj_data.groupby('id').max()
reason_data = pd.DataFrame(reason_data)
reason_data = pd.concat([reason_data['latest_status'],reason_data['totalkgds'],reason_data['pickup_city'],reason_data['dropoff_city'] ,reason_data['pickup_address_type'], reason_data['dropoff_address_type'],
                  reason_data['category'], reason_data['price_type'], 
                  reason_data['shipment_type'], reason_data['vehicle_type'],reason_data['vehicle_body_type'],
                  reason_data['vehicle_package_type'], reason_data['vehicle_way_of_loading'],
                  reason_data['vehicle_tonnage_per_vehicle'],reason_data['payment_option'],
                  reason_data['invoice_type'], reason_data['tenant_signup_flow'], 
                  reason_data['total_trip_cost_amount_in_tl'], reason_data['usd_tl'],
                  reason_data['price_base_amount_in_tl']
                 ,reason_data['routes'],reason_data['km'],reason_data['kursunsuz_v_max'],reason_data['pro_dizel']], axis = 1)
reason_data
reason_data = reason_data.drop(columns = 'shipment_type')
reason_data = reason_data.drop(columns = 'latest_status')
reason_data = reason_data.drop(columns = 'price_base_amount_in_tl')
reason_data = reason_data.drop(columns = 'price_type')
reason_data = reason_data.drop(columns = 'payment_option')
reason_data = reason_data.drop(columns = 'invoice_type')
reason_data = reason_data.drop(columns = 'tenant_signup_flow')
reason_data

# %%
reason_data = reason_data[reason_data.routes == 'Bursa_Kocaeli']
reason_data = reason_data[reason_data.vehicle_body_type == 'FLATBED']
reason_data = reason_data[reason_data.vehicle_package_type == 'OTHER']
reason_data.sort_values(by = 'kursunsuz_v_max', ascending= False)

# %%
reason_data.index.isin(three_mse_shipments.index)

# %%
pd.set_option('display.max_rows', 500)
